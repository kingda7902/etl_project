# %% [markdown]
# ## read data from a folder
#
#
# `os.walk` return tuple (dirpath, dirnames, filenames)
#
# ---
# # transfer
# - [school](#school)

# %%
#return a dict key:path value:filenames
from os import walk

def getFilesPath(path = './'):
    pathlist = {}
    for (dirpath, dirnames, filenames) in walk(path):
        for name in dirnames:
            nowpath = dirpath + '/'+ name
            pathlist.update(getFilesPath(nowpath))
        pathlist[dirpath] = filenames
        break
    return pathlist

# %%
data = getFilesPath('./data')
data
# Out:
# {'./data': [],
#  './data/104': ['Job_104_1001.json',
#   'Job_104_1002.json',
#   'Job_104_1003.json',
#   'Job_104_1004.json',
#   'Job_104_1005.json',
#   'Job_104_1006.json',
#   'Job_104_1007.json',
#   'Job_104_1008.json',
#   'Job_104_1009.json',
#   'Job_104_1010.json',
#   'Job_104_1011.json',
#   'Job_104_1012.json',
#   'Job_104_2001.json',
#   'Job_104_2002.json',
#   'Job_104_2003.json',
#   'Job_104_2004.json',
#   'Job_104_2005.json',
#   'Job_104_2006.json',
#   'Job_104_2007.json',
#   'Job_104_2008.json',
#   'test104.json',
#   'test104_beauty.json'],
#  './data/1111': ['1111_Get_C#_d0All.json',
#   '1111_Get_C++_d0All.json',
#   '1111_Get_C_d0All.json',
#   '1111_Get_HADOOP_d0All.json',
#   '1111_Get_HTML_d0All.json',
#   '1111_Get_JavaScript_d0All.json',
#   '1111_Get_Java_d0All.json',
#   '1111_Get_Linux_d0All.json',
#   '1111_Get_Mongo DB_d0All.json',
#   '1111_Get_PHP_d0All.json',
#   '1111_Get_PYTHON_d0All.json',
#   '1111_Get_SQL_d0All.json',
#   '1111_Get_大數據分析師_d0All.json',
#   '1111_Get_資料分析師_d0All.json',
#   '1111_Get_軟體設計工程師_d0All.json'],
#  './data/518': ['518_Get_Java_ab2032001.json',
#   '518_Get_PHP_ab2032001.json',
#   '518_Get_工程師_ab2032001.json',
#   '518_Get_軟體設計工程師_ab2032001.json']}

# %%
for dirname in data.keys():
    print(data[dirname])
# Out:
# []
# ['Job_104_1001.json', 'Job_104_1002.json', 'Job_104_1003.json', 'Job_104_1004.json', 'Job_104_1005.json', 'Job_104_1006.json', 'Job_104_1007.json', 'Job_104_1008.json', 'Job_104_1009.json', 'Job_104_1010.json', 'Job_104_1011.json', 'Job_104_1012.json', 'Job_104_2001.json', 'Job_104_2002.json', 'Job_104_2003.json', 'Job_104_2004.json', 'Job_104_2005.json', 'Job_104_2006.json', 'Job_104_2007.json', 'Job_104_2008.json', 'test104.json', 'test104_beauty.json']
# ['518_Get_Java_ab2032001.json', '518_Get_PHP_ab2032001.json', '518_Get_工程師_ab2032001.json', '518_Get_軟體設計工程師_ab2032001.json']
# ['1111_Get_C#_d0All.json', '1111_Get_C++_d0All.json', '1111_Get_C_d0All.json', '1111_Get_HADOOP_d0All.json', '1111_Get_HTML_d0All.json', '1111_Get_JavaScript_d0All.json', '1111_Get_Java_d0All.json', '1111_Get_Linux_d0All.json', '1111_Get_Mongo DB_d0All.json', '1111_Get_PHP_d0All.json', '1111_Get_PYTHON_d0All.json', '1111_Get_SQL_d0All.json', '1111_Get_大數據分析師_d0All.json', '1111_Get_資料分析師_d0All.json', '1111_Get_軟體設計工程師_d0All.json']

# %% [markdown]
# ## read json test

# %%
import json

filepath = './data/104/Job_104_1001.json'
with open(filepath, encoding = 'utf8') as f:
    datas = json.load(f)

# %%
datas['job_lists'][0]
# Out:
# {'company': '香港商慧科訊業有限公司台灣分公司',
#  'content': '高級軟體研發經理 (Senior Software Development Manager)\n\n工作內容\n* 台灣研發團隊組織及績效控管\n* 設計/規劃/開發商業智慧(BI)系統\n* 專案管理及需求訪談\n* AWS雲端服務架構分析、概念驗證、移轉規劃與實施\n* AWS雲端產品導入及技術支持',
#  'other_condition': '需求條件：電機/資訊科學/資訊工程相關學科，學士以上\n          十年以上軟體研發相關工作經驗\n          三年以上專案管理相關工作經驗\n\n加分條件：具備 BI 相關工作經驗優先\n          (Kinesis Stream, SQS, DynamoDB, ECS etc)\n          熟悉Java, Spring-MVC, Struts, MySQL, MongoDB\n          熟悉Linux 操作系統',
#  'post_date': '更新日期：2017-07-03',
#  'skills': '軟體程式設計、網路程式設計',
#  'title': '高級軟體研發經理 Senior Software Development Manager',
#  'tools': 'Linux、Java、Spring、Struts、Tomcat、jQuery',
#  'url': 'https://www.104.com.tw/job/?jobno=5jl00&jobsource=104_hotorder'}

# %% [markdown]
# ## transfer
#
# [top 20 programming languages](https://jaxenter.com/the-top-20-programming-languages-the-githut-and-tiobe-rankings-108100.html)
# [TIOBE](https://www.tiobe.com/tiobe-index/)

# %% [markdown]
# ## classify
# some 'tools' have no info

# %%
for i in datas['job_lists']:
    print(i['tools'].upper().split('、'))
# Out:
# ['LINUX', 'JAVA', 'SPRING', 'STRUTS', 'TOMCAT', 'JQUERY']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['PHP']
# ['PHP']
# ['不拘']
# ['C', 'C#', 'PHP', 'VISUAL BASIC', 'MYSQL', 'HTML', 'JAVASCRIPT', 'JQUERY']
# ['C', 'C#', 'PHP', 'VISUAL BASIC', 'MYSQL', 'HTML', 'JAVASCRIPT', 'JQUERY']
# ['LINUX', 'ANDROID', 'JAVA', 'MYSQL', 'POSTGRESQL']
# ['不拘']
# ['不拘']
# ['不拘']
# ['EXCEL', 'POWERPOINT', 'VISIO', 'WORD']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['C#', 'C++']
# ['不拘']
# ['不拘']
# ['UNITY3D']
# ['ASP.NET', 'MS SQL']
# ['ASP.NET', 'MS SQL']
# ['LINUX', 'MAC OS', 'WINDOWS 7', 'AJAX', 'C++', 'JAVA', 'PHP', 'MYSQL', 'HTML', 'JAVASCRIPT', 'XML', 'FTP', 'HTTP', 'TCP/IP', 'EXCEL', 'POWERPOINT']
# ['C', 'C++', 'JAVA', 'PHP', 'VISUAL STUDIO', 'MS SQL', 'MYSQL', 'JAVASCRIPT', 'XHTML', 'XML']
# ['不拘']
# ['不拘']
# ['不拘']
# ['LINUX', 'SHELL', 'C', 'C++', 'JAVA', 'PERL', 'PYTHON']
# ['JSP', 'ACTIVEX', 'HTML', 'JQUERY', 'SOCKET']
# ['不拘']
# ['LINUX', 'MCU', 'C', 'C++']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['ACTIONSCRIPT', 'C', 'C#', 'C++', 'C++.NET', 'JAVA', 'OBJECTIVE-C', 'MS SQL', 'MYSQL', 'HTML', 'JAVASCRIPT', 'XML WEB SERVICES', 'HTTP', 'IIS', 'TCP/IP']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['C#', 'JAVA', 'VISUAL BASIC .NET', 'MYSQL', 'ORACLE', 'XML', 'JQUERY', '鼎新']
# ['不拘']
# ['不拘']
# ['OOAD', 'SYSTEMS ANALYSIS', 'UML', 'DATA MODELING']
# ['不拘']
# ['不拘']
# ['DATABASE MANAGEMENT', 'MS SQL', 'MYSQL']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['LABVIEW', 'EXCEL', 'OUTLOOK', 'POWERPOINT', 'WORD', '中文打字20~50']
# ['LINUX', 'UNIX', 'WINDOWS SERVER 2008', 'OOAD', 'OOP', 'SDLC', 'SYSTEMS ANALYSIS', 'AJAX', 'JAVA', 'JMS', 'JSF', 'JSP', 'SPRING', 'STRUTS', 'INFORMIX', 'JDBC', 'MS SQL', 'ORACLE', 'PL/SQL', 'SYSBASE']
# ['LINUX', 'UNIX', 'WINDOWS SERVER 2008', 'OOAD', 'OOP', 'SDLC', 'SYSTEMS ANALYSIS', 'UML', 'AJAX', 'JAVA', 'JMS', 'JSF', 'JSP', 'SPRING', 'STRUTS', 'INFORMIX', 'JDBC', 'MS SQL', 'ORACLE', 'PL/SQL', 'SYSBASE']
# ['LINUX', 'UNIX', 'WINDOWS SERVER 2008', 'OOAD', 'OOP', 'SDLC', 'SYSTEMS ANALYSIS', 'UML', 'JAVA', 'JMS', 'JSF', 'SPRING', 'STRUTS', 'INFORMIX', 'JDBC', 'MS SQL', 'ORACLE', 'PL/SQL', 'SYSBASE']
# ['UNIX', 'DEVELOPER/ DESIGNER 2000']
# ['OS/400', 'RPG']
# ['OS/400', 'UNIX', 'RPG']
# ['不拘']
# ['不拘']
# ['不拘']
# ['ASP.NET', 'C#', 'MS SQL', 'JAVASCRIPT', 'JQUERY']
# ['LINUX', 'WINDOWS SERVER 2012', 'OOAD', 'OOP', 'SYSTEMS ANALYSIS', 'UML', 'AJAX', 'ASP.NET', 'C', 'C#', 'C++', 'VISUAL C++', 'VISUAL STUDIO .NET', 'MS SQL', 'ORACLE', 'POSTGRESQL', 'TCP/IP', 'PLC']
# ['不拘']
# ['ASP.NET', 'C#']
# ['不拘']
# ['IOS', 'OBJECTIVE-C']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['C', 'C++', 'MFC', 'ETHERNET', 'HTTP', 'SOCKET', 'TCP/IP', 'ARM', 'ASSEMBLY']
# ['不拘']
# ['PYTHON', 'MYSQL', 'HTML', 'JAVASCRIPT', 'TCP/IP']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['LINUX', 'JAVA', 'TOMCAT', 'JUNIT']
# ['LINUX', 'WINDOWS SERVER 2008', 'AJAX', 'ASP.NET', 'JAVA']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['EXCEL', 'OUTLOOK', 'POWERPOINT', 'WORD']
# ['不拘']
# ['OOP', 'C++']
# ['EXCEL', 'OUTLOOK', 'POWERPOINT', 'PROJECT', 'VISIO', 'WORD']
# ['不拘']
# ['LINUX', 'ANDROID', 'MCU', 'OOP', 'C', 'C#', 'C++', 'C++.NET', 'JAVA', 'CITRIX', 'MICROSOFT EXCHANGE', 'MICROSOFT SHAREPOINT', 'TOMCAT', 'VMWARE', 'WEBLOGIC', 'CISCO', 'DHCP', 'DNS', 'ETHERNET', 'FIREWALL', 'FTP', 'HTTP', 'HUBS/ ROUTERS', 'SECURITY', 'TCP/IP']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['LINUX', 'C++']
# ['不拘']
# ['不拘']
# ['EXCEL', 'POWERPOINT', 'PROJECT', 'WORD']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['EXCEL', 'OUTLOOK', 'POWERPOINT', 'WORD', '中文打字20~50', '英文打字20~50']
# ['不拘']
# ['不拘']
# ['JAVA', 'OBJECTIVE-C', 'SWIFT']
# ['不拘']
# ['不拘']
# ['SAP']
# ['不拘']
# ['LINUX', 'MAC OS', 'ANDROID', 'IOS', 'JAVA']
# ['不拘']
# ['不拘']
# ['DOS', 'WINDOWS SERVER 2012', 'MS SQL', 'SYSBASE', 'EXCEL', 'INTERNET EXPLORER', 'OUTLOOK', 'PROJECT', 'WORD', '中文打字50~75', '英文打字50~75', 'AUTOCAD', 'MICROSTRATEGY', 'MRP', '鼎新', '文中系統']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['FREEBSD', 'LINUX', 'SOLARIS', 'SUN OS', 'C++', 'JAVA', 'JSP', 'DB2', 'MS SQL', 'MYSQL', 'ORACLE', 'DREAMWEAVER', 'FIREWORKS', 'HTML', 'FLASH', 'ADOBE PHOTOSHOP', 'ILLUSTRATOR']
# ['LINUX', 'OOAD', 'OOP', 'SERVLETS', 'UML', 'JAVA', 'JSP', 'JDBC', 'MYSQL', 'RDBMS', 'TOMCAT', 'HTML', 'J2EE', 'J2SE', 'JAVASCRIPT', 'JQUERY']
# ['C#', 'C++', 'JAVA', 'MS SQL', 'MYSQL', 'ORACLE', 'SYBASE']
# ['UML', 'AJAX', 'ASP.NET', 'C++.NET', 'JAVA', 'JSP', 'PHP', 'MS SQL', 'MYSQL', 'ORACLE', 'COLD FUSION', 'JAVASCRIPT', 'XML']
# ['UML', 'JAVA', 'OBJECTIVE-C']
# ['JAVA', 'SPRING', 'ORACLE', 'TOMCAT', 'HTML', 'XML', 'JQUERY']
# ['JAVA', 'SPRING', 'ORACLE', 'TOMCAT', 'HTML', 'XML', 'JQUERY']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['OOP', 'SDLC', 'UML', 'ASP.NET', 'VISUAL C#', 'MS SQL', 'WEB MASTER/DEVELOPER', 'EXCEL', 'POWERPOINT', 'PROJECT', 'VISIO', 'WORD']
# ['ASP.NET', 'C#', 'HTML', 'JAVASCRIPT', 'IIS']
# ['C++']
# ['不拘']
# ['不拘']
# ['不拘']
# ['LINUX', 'ADA', 'C', 'C++', 'VISUAL C++']
# ['SERVLETS', 'JAVA', 'JSP', 'MS SQL', 'ORACLE', 'PL/SQL', 'JAVASCRIPT', 'XML', 'JQUERY']
# ['LINUX', 'C', 'C#', 'JAVA', 'TCP/IP']
# ['LINUX', 'C', 'C#', 'JAVA', 'TCP/IP']
# ['不拘']
# ['C', 'PYTHON']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['DIRECTX', 'VISUAL C#', 'VISUAL C++', 'DATABASE MANAGEMENT', 'TCP/IP', 'UDP', 'RTSP']
# ['C', 'C++', 'CGI']
# ['不拘']
# ['MAC OS', 'WINDOWS 2000', 'WINDOWS NT', 'WINDOWS XP', 'EXCEL', 'OUTLOOK', 'POWERPOINT', 'WORD']
# ['不拘']
# ['不拘']
# ['C', 'C++', 'VISUAL STUDIO', 'ASSEMBLY']
# ['VISUAL STUDIO .NET', 'MS SQL', 'DHTML', 'JAVASCRIPT', 'JQUERY']
# ['不拘']
# ['C#', 'JAVA']
# ['ANDROID', 'PHP', 'SWIFT', 'HTML']
# ['ANDROID', 'SYSTEMS ANALYSIS', 'SYSTEMS ANALYST', 'UML', 'PHP', 'SWIFT', 'HTML']
# ['UML', 'C', 'OBJECTIVE-C']
# ['UML', 'C', 'JAVA', 'J2SE']
# ['LINUX', 'ANDROID']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['C#', 'C++', 'MS SQL']
# ['不拘']
# ['C', 'C++']
# ['不拘']
# ['不拘']
# ['LINUX', 'SYSTEMS ANALYSIS', 'AJAX', 'JAVA', 'PHP', 'MYSQL', 'HTML', 'JAVASCRIPT', 'JQUERY']
# ['LINUX', 'SYSTEMS ANALYSIS', 'AJAX', 'JAVA', 'PHP', 'MYSQL', 'POSTGRESQL', 'HTML', 'JAVASCRIPT', 'JQUERY']
# ['不拘']
# ['不拘']
# ['不拘']
# ['DATA MODELING', 'DATABASE ADMINISTRATOR', 'DATABASE MANAGEMENT', 'DATASTAGE', 'ETL', 'INFORMATICA']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['EXCEL', 'OUTLOOK', 'POWERPOINT', 'WORD']
# ['EXCEL', 'OUTLOOK', 'POWERPOINT', 'WORD']
# ['EXCEL', 'OUTLOOK', 'POWERPOINT', 'WORD']
# ['LINUX', 'MAC OS', 'OS X', 'C#', 'C++', 'JAVA', 'MS SQL', 'MYSQL', 'JAVASCRIPT', 'JQUERY', 'FTP', 'HTTP', 'IIS', 'POWERPOINT', 'WORD']
# ['不拘']
# ['不拘']
# ['LINUX', 'ASP.NET', 'JAVA', 'PHP', 'MS SQL', 'ORACLE', '鼎新']
# ['LINUX', 'ASP.NET', 'JAVA', 'PHP', 'MS SQL', 'ORACLE', '鼎新']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['LINUX', 'C', 'C++', 'VISUAL C++', 'TCP/IP', 'WLAN']
# ['C', 'C++', 'VISUAL C++', 'TCP/IP', 'ARM', 'DRIVERS', 'FIRMWARE']
# ['MCU', 'C', 'C++', 'ARM']
# ['不拘']
# ['不拘']
# ['不拘']
# ['C', 'C++']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['OS X', '中文打字50~75', '英文打字50~75']
# ['不拘']
# ['HTTP', 'SOCKET', 'TCP/IP', 'EXCEL', 'POWERPOINT', 'WORD', '中文打字20~50', '英文打字20~50']
# ['HTTP', 'SOCKET', 'TCP/IP', 'EXCEL', 'POWERPOINT', 'WORD', '中文打字20~50', '英文打字20~50']
# ['HTTP', 'SOCKET', 'TCP/IP', 'EXCEL', 'POWERPOINT', 'WORD', '中文打字20~50', '英文打字20~50']
# ['LINUX', 'C', 'C++', 'JAVA', 'JSP', 'PYTHON', 'RUBY']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['C++', 'JAVA', 'PYTHON', 'DATABASE MANAGEMENT']
# ['不拘']
# ['不拘']
# ['不拘']
# ['OOAD', 'OOP', 'SYSTEMS ANALYSIS', 'UML']
# ['不拘']
# ['不拘']
# ['不拘']
# ['WINDOWS 7', 'WINDOWS SERVER 2008', 'ANDROID', 'IOS', 'WINDOWS 8', 'WINDOWS SERVER 2012', 'JAVA', 'OBJECTIVE-C', 'IMS', 'HTTP', 'TCP/IP', 'EXCEL', 'OUTLOOK', 'POWERPOINT', 'WORD', 'RTSP']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['JAVASCRIPT']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['PHP', 'MS SQL', 'MYSQL', 'DHTML', 'HTML', 'JAVASCRIPT', 'JQUERY']
# ['DREAMWEAVER', 'HTML', 'JAVASCRIPT']
# ['ANDROID', 'JAVA']
# ['IOS', 'C++', 'OBJECTIVE-C', 'SWIFT']
# ['不拘']
# ['ASP.NET', 'C#', 'C++.NET', 'DHTML']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['C++', 'JAVASCRIPT']
# ['EXCEL', 'OUTLOOK', 'POWERPOINT', 'PROJECT', 'WORD']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['ASP.NET', 'C#', 'MS SQL', 'ORACLE']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['AJAX', 'ASP.NET', 'PHP', 'MYSQL', 'APACHE SOAP', 'HTML', 'JAVASCRIPT', 'JQUERY', 'IIS']
# ['不拘']
# ['C', 'C++']
# ['不拘']
# ['不拘']
# ['AJAX', 'JAVA', 'PYTHON', 'RUBY', 'SPRING']
# ['C', 'C++']
# ['C#', 'C++.NET', 'JAVA', 'MS SQL', 'MYSQL', 'ORACLE']
# ['不拘']
# ['不拘']
# ['EXCEL', 'POWERPOINT', 'PROJECT', 'WORD']
# ['EXCEL', 'POWERPOINT', 'PROJECT', 'WORD']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['EXCEL', 'OUTLOOK', 'POWERPOINT', 'PROJECT', 'VISIO', 'WORD']
# ['不拘']
# ['LINUX', 'AJAX', 'JAVA', 'JSP', 'SPRING', 'STRUTS', 'MYSQL', 'ORACLE', 'TOMCAT', 'JAVASCRIPT', 'JQUERY']
# ['LINUX', 'AJAX', 'JAVA', 'JSF', 'JSP', 'SPRING', 'STRUTS', 'MS SQL', 'MYSQL', 'ORACLE', 'TOMCAT', 'VMWARE', 'WEBLOGIC', 'JAVASCRIPT', 'JQUERY']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['AJAX', 'JAVA', 'MS SQL', 'MYSQL', 'ORACLE', 'HTML', 'JAVASCRIPT', 'JQUERY']
# ['AJAX', 'JAVA', 'MS SQL', 'MYSQL', 'ORACLE', 'DHTML', 'HTML', 'J2EE', 'JAVASCRIPT', 'JQUERY']
# ['ASP.NET', 'JAVA', 'PHP', 'VISUAL BASIC', 'VISUAL BASIC .NET', 'VISUAL STUDIO', 'VISUAL STUDIO .NET', 'ADO', 'MS SQL', 'ODBC', 'ORACLE', 'HTML', 'JAVASCRIPT', 'VBSCRIPT', 'XML']
# ['OOP', 'STL', 'C++', 'VISUAL C++']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['LINUX', 'C', 'C++']
# ['ASP.NET', 'C#', 'VISUAL BASIC .NET', 'VISUAL STUDIO .NET', 'WINFORM', 'MS SQL', 'DHTML', 'DREAMWEAVER', 'HTML', 'JQUERY']
# ['ASP.NET', 'C#', 'WINFORM', 'MS SQL']
# ['不拘']
# ['不拘']
# ['C++']
# ['不拘']
# ['ORACLE FORMS', 'ORACLE', 'CISCO', 'ORACLE FINANCIALS', 'ORACLE ERP']
# ['不拘']
# ['OBJECTIVE-C', 'SWIFT']
# ['不拘']
# ['不拘']
# ['ORACLE ERP', 'SAP']
# ['不拘']
# ['C', 'C++', 'JAVA', 'VISUAL C++']
# ['C#', 'VISUAL STUDIO']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['JAVASCRIPT']
# ['JAVA', 'J2EE', 'JAVASCRIPT']
# ['AIX', 'LINUX', 'WINDOWS 7', 'WINDOWS SERVER 2008', 'SYSTEMS ADMINISTRATION', 'SYSTEMS ANALYSIS', 'SYSTEMS ANALYST', 'C', 'VISUAL BASIC .NET', 'VISUAL STUDIO .NET', 'WIN32', 'MS SQL', 'ORACLE', 'TOMCAT', 'ACTIVEX', 'HTML', 'XML', 'EXCEL', 'POWERPOINT', 'WORD']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['WINDOWS 7', 'WINDOWS 8']
# ['LINUX', 'C++']
# ['POWERBUILDER', 'ORACLE']
# ['不拘']
# ['不拘']
# ['JAVA', 'JSP', 'SPRING', 'STRUTS', 'MS SQL', 'MYSQL', 'ORACLE']
# ['C#', 'JAVA', 'JSP']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['ANDROID', 'C', 'C++']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['LINUX', 'C', 'C++', 'PERL', 'PYTHON', 'HTML', 'JAVASCRIPT']
# ['不拘']
# ['LINUX', 'AJAX', 'JAVA', 'SPRING', 'STRUTS', 'MYSQL', 'J2EE', 'JQUERY']
# ['不拘']
# ['不拘']
# ['不拘']
# ['ASP.NET', 'C#', 'MS SQL', 'JAVASCRIPT']
# ['ASP.NET', 'C#', 'MS SQL', 'JAVASCRIPT']
# ['ASP.NET', 'C#', 'MS SQL', 'JAVASCRIPT']
# ['ASP.NET', 'C#', 'MS SQL', 'JAVASCRIPT']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['AJAX', 'HTML', 'JAVASCRIPT', 'JQUERY']
# ['不拘']
# ['SHELL', 'JAVA', 'PHP', 'PYTHON', 'MYSQL', 'ORACLE', 'POSTGRESQL', 'HTML', 'JAVASCRIPT', 'HTTP']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['ASP', 'C#', 'WINFORM']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['C', 'C++', 'UNITY3D']
# ['C', 'C#', 'C++']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['AJAX', 'ASP.NET', 'MS SQL', 'JQUERY']
# ['EXCEL', 'POWERPOINT', 'PROJECT', 'VISIO', 'WORD']
# ['ASP.NET', 'VISUAL BASIC .NET', 'MS SQL', 'ORACLE']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['LINUX', 'WINDOWS SERVER 2008', 'JAVA', 'ORACLE', 'VMWARE', 'HTML', 'CISCO', 'JUNIPER', 'EXCEL', 'VISIO', 'SAN/NAS', 'VERITAS', '鼎新']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['C#', 'JAVA', 'OBJECTIVE-C', 'SWIFT', 'HTML', 'JAVASCRIPT']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['EXCEL', 'POWERPOINT', 'WORD']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['ASP', 'ASP.NET', 'C#', 'PHP', 'VISUAL STUDIO', 'VISUAL STUDIO .NET', 'MS SQL', 'MYSQL', 'DHTML', 'HTML', 'JAVASCRIPT', 'XML', 'XML WEB SERVICES', 'JQUERY']
# ['C++', 'PYTHON']
# ['C++', 'PYTHON']
# ['C', 'C#', 'C++', 'FPGA']
# ['C#', 'DELPHI', 'JAVA']
# ['C#', 'MS SQL', 'JAVASCRIPT']
# ['SAP']
# ['C#', 'DELPHI', 'JAVA']
# ['不拘']
# ['不拘']
# ['C#', 'C++.NET', 'ORACLE']
# ['不拘']
# ['LINUX', 'SERVLETS', 'C', 'C++', 'JAVA', 'JDBC', 'DHTML', 'HTML', 'JAVASCRIPT', 'JQUERY']
# ['C++', 'MFC', 'VISUAL C++']
# ['C++', 'C++.NET', 'MFC', 'VISUAL C++']
# ['不拘']
# ['C#', 'C++', 'C++.NET', 'MATLAB', 'PHP', 'PYTHON', 'OBJECTIVE-C']
# ['不拘']
# ['C++', 'C++.NET', 'VISUAL BASIC .NET', 'VISUAL C++']
# ['不拘']
# ['C', 'C#', 'C++', 'MATLAB']
# ['不拘']
# ['ASP.NET', 'C#', 'MS SQL']
# ['JAVA']
# ['不拘']
# ['C#', 'JAVA', 'VISUAL C#', 'VISUAL J#', 'UNITY3D']
# ['OOAD', 'OOP', 'SDLC', 'SERVLETS', 'SYSTEMS ANALYST', 'UML', 'AJAX', 'JAVA', 'JSP', 'SPRING', 'STRUTS']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['LINUX', 'AJAX', 'C', 'PHP', 'HTML', 'JAVASCRIPT', 'JQUERY', 'SOCKET', 'TCP/IP', 'UDP']
# ['JAVA', 'MS SQL', 'ORACLE', 'POSTGRESQL']
# ['JAVA', 'MS SQL', 'ORACLE', 'POSTGRESQL']
# ['JAVA', 'MS SQL', 'ORACLE', 'POSTGRESQL']
# ['UNIX', 'WINDOWS NT', 'COBOL', 'JAVA', 'DB2', 'RDBMS', 'WEBSPHERE']
# ['ASP', 'ASP.NET', 'C#', 'VBA', 'MS SQL', 'ORACLE', 'JAVASCRIPT', '鼎新']
# ['不拘']
# ['LINUX', 'JAVA', 'JSP', 'JDBC', 'MYSQL', 'MQSERIES', 'TOMCAT', 'J2EE', 'HTTP', 'SOCKET']
# ['LINUX', 'SHELL', 'OOAD', 'OOP', 'SDLC', 'SERVLETS', 'UML', 'ACTIONSCRIPT', 'JAVA', 'JSP', 'PHP', 'SPRING', 'ANSI SQL', 'DATA MODELING', 'ETL', 'JDBC', 'MYSQL', 'ODBC', 'ORACLE', 'TOMCAT', 'EJB', 'HTML', 'J2EE', 'J2SE', 'JAVASCRIPT', 'XML', 'XML WEB SERVICES', 'JQUERY', 'FTP', 'HTTP', 'SNIFFER', 'SOCKET', 'TCP/IP']
# ['DELPHI', 'MS SQL']
# ['不拘']
# ['不拘']
# ['不拘']
# ['LINUX', 'C', 'C#', 'JAVA', 'TCP/IP']
# ['LINUX', 'C', 'C#', 'JAVA', 'TCP/IP']
# ['LINUX', 'C', 'C#', 'JAVA', 'TCP/IP']
# ['LINUX', 'ANDROID', 'IOS', 'JAVA', 'PHP', 'RUBY']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['LINUX', 'ANDROID', 'IOS', 'C#', 'C++', 'JAVA', 'OBJECTIVE-C', 'SWIFT', 'HTML']
# ['DELPHI']
# ['APPLE', 'LINUX', 'MAC OS', 'OS X', 'ANDROID', 'IOS', 'WINDOWS SERVER 2012', 'AJAX', 'ASP.NET', 'C', 'C++', 'DIRECTX', 'JAVA', 'JSP', 'MICROSOFT EXCHANGE', 'SILVERSTREAM', 'TOMCAT', 'VMWARE', 'CISCO', 'DHCP', 'DNS', 'EDI', 'FIREWALL', 'FTP', 'HTTP', 'HUBS/ ROUTERS', 'IIS', 'SAN', 'SOAP', 'VLAN', 'WAN']
# ['不拘']
# ['不拘']
# ['JAVA', 'ORACLE', 'PL/SQL']
# ['LINUX', 'C']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['鼎新']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['PROJECT']
# ['不拘']
# ['LINUX', 'C', 'C++']
# ['LINUX']
# ['AJAX', 'ASP.NET', 'C#', 'MS SQL']
# ['LINUX', 'ANDROID']
# ['不拘']
# ['EXCEL', 'OUTLOOK', 'PROJECT', 'WORD']
# ['不拘']
# ['不拘']
# ['ASP.NET', 'C#', 'MS SQL']
# ['C', 'C++', 'JAVA']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['PHP', 'HTML', 'JAVASCRIPT']
# ['不拘']
# ['C#', 'VISUAL BASIC .NET']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['PHP']
# ['不拘']
# ['WINDOWS SERVER 2012', 'MS SQL', 'HTML', 'JAVASCRIPT', 'EXCEL', 'POWERPOINT', 'PROJECT', 'WORD']
# ['不拘']
# ['HTML', 'ADOBE PHOTOSHOP', 'ILLUSTRATOR']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['C++', 'C++.NET', 'VISUAL C++', 'MS SQL']
# ['C++', 'C++.NET', 'MFC', 'VISUAL C++', 'MS SQL']
# ['EXCEL', 'OUTLOOK', 'POWERPOINT', 'WORD']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['LINUX', 'C', 'C++', 'JAVA', 'PYTHON']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['EXCEL', 'OUTLOOK', 'POWERPOINT', 'WORD']
# ['不拘']
# ['不拘']
# ['不拘']
# ['C#', 'C++']
# ['LINUX', 'AJAX', 'JAVA', 'JSP', 'SPRING', 'STRUTS', 'MYSQL', 'TOMCAT', 'JAVASCRIPT', 'JQUERY']
# ['不拘']
# ['不拘']
# ['ADOBE PHOTOSHOP', '鼎新']
# ['EXCEL', 'POWERPOINT', 'WORD']
# ['JAVA', 'ANSI SQL', 'EXCEL', 'POWERPOINT', 'PROJECT', 'WORD']
# ['WINDOWS 2000', 'WINDOWS NT', 'ASP', 'MS SQL', 'EXCEL', 'POWERPOINT', 'WORD']
# ['AJAX', 'C#', 'JAVA', 'MS SQL', 'ORACLE', 'JAVASCRIPT', 'JQUERY聯絡人：']
# ['ORACLE', 'PL/SQL', 'SAP']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['LINUX', 'PHP', 'MYSQL', 'JAVASCRIPT']
# ['ORACLE FORMS', 'ORACLE', 'PL/SQL']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['C', 'C++', 'EXCEL', 'OUTLOOK', 'POWERPOINT', 'WORD']
# ['不拘']
# ['C', 'C++']
# ['C', 'C++']
# ['不拘']
# ['JAVA', 'SPRING']
# ['EXCEL', 'POWERPOINT', 'WORD']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['AJAX', 'PHP', 'MYSQL', 'POSTGRESQL', 'JAVASCRIPT']
# ['LINUX', 'JAVA', 'SPRING', 'STRUTS', 'MYSQL']
# ['不拘']
# ['不拘']
# ['C', 'C++', 'C++.NET']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['ORACLE', 'ORACLE ERP']
# ['不拘']
# ['LINUX', 'ANDROID', 'C++', 'JAVA', 'MS SQL', 'JAVASCRIPT', 'XML', 'TCP/IP']
# ['不拘']
# ['不拘']
# ['不拘']
# ['AJAX', 'ASP', 'ASP.NET', 'C#', 'MS SQL', 'HTML', 'JAVASCRIPT']
# ['JAVA']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['C', 'JAVA', 'MYSQL', 'HTML', 'JAVASCRIPT', 'JQUERY']
# ['不拘']
# ['不拘']
# ['不拘']
# ['C', 'C++', 'VISUAL BASIC', 'VISUAL BASIC .NET', 'VISUAL C++']
# ['不拘']
# ['C', 'ASSEMBLY', 'PROTEL']
# ['ASP.NET', 'C#', 'HTML', 'JQUERY']
# ['不拘']
# ['VBSCRIPT', 'EXCEL']
# ['ANDROID', 'JAVA']
# ['不拘']
# ['ANDROID', 'IOS', 'JAVA', 'OBJECTIVE-C']
# ['不拘']
# ['不拘']
# ['不拘']
# ['JAVA', 'SPRING', 'MS SQL', 'ORACLE']
# ['不拘']
# ['ASP.NET', 'C#', 'MS SQL']
# ['JAVA', 'SPRING', 'STRUTS', 'JAVASCRIPT']
# ['不拘']
# ['不拘聯絡人：']
# ['不拘']
# ['不拘聯絡人：']
# ['LINUX', 'RUBY', 'HTML', 'JAVASCRIPT']
# ['LINUX', 'RUBY', 'RDBMS']
# ['不拘']
# ['LINUX', 'ANDROID', 'IOS', 'AJAX', 'ASP.NET', 'C#', 'JAVA', 'JSP', 'OBJECTIVE-C', 'SWIFT', 'DATABASE MANAGEMENT', 'MS SQL', 'MYSQL', 'ORACLE', 'JAVASCRIPT', 'JQUERY']
# ['ASP.NET', 'C#', 'C++.NET', 'VISUAL BASIC .NET', 'VISUAL STUDIO .NET']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['ASP.NET', 'C#', 'C++', 'VISUAL STUDIO', 'MS SQL']
# ['不拘']
# ['C', 'C#', 'C++', 'C++.NET', 'VISUAL C#', 'VISUAL C++', 'UNITY3D']
# ['C', 'C#', 'C++', 'C++.NET', 'VISUAL C#', 'VISUAL C++', 'UNITY3D']
# ['不拘']
# ['不拘']
# ['WINDOWS SERVER 2008', 'WINDOWS SERVER 2012', 'OOAD', 'OOP', 'ASP.NET', 'C#', 'COM/DCOM', 'VISUAL SOURCESAFE', 'VISUAL STUDIO', 'VISUAL STUDIO .NET', 'ADO', 'DATA MODELING', 'DATABASE ADMINISTRATOR', 'DATABASE MANAGEMENT', 'MS SQL', 'DHTML', 'HTML', 'XML', 'XML WEB SERVICES', 'JQUERY']
# ['LINUX', 'JAVA', 'PHP', 'PYTHON', 'MYSQL', 'PL/SQL', 'HTML']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['OOAD', 'SYSTEMS ANALYSIS', 'UML', 'DHTML', 'HTML', 'XHTML', 'XML', 'EXCEL', 'POWERPOINT', 'PROJECT']
# ['JAVA', 'EXCEL', 'OUTLOOK', 'POWERPOINT', 'PROJECT', 'VISIO', 'WORD']
# ['JAVA', 'SAP']
# ['ASP.NET', 'C#', 'C++', 'WINFORM', 'MS SQL', 'ORACLE']
# ['不拘']
# ['不拘']
# ['LINUX', 'UNIX', 'ANDROID', 'IOS']
# ['C']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['C#', 'PYTHON']
# ['JAVA', 'SPRING']
# ['不拘']
# ['ASP.NET', 'C++', 'JAVA', 'PHP', 'MYSQL']
# ['不拘']
# ['WINDOWS 2000', 'WINDOWS NT', 'OOP', 'ASP.NET', 'C', 'C#', 'C++', 'DELPHI', 'VISUAL BASIC', 'VISUAL C#', 'MS SQL', 'OUTLOOK', 'WORD']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['SAP']
# ['不拘']
# ['LINUX', 'WINDOWS XP', 'WINDOWS 7', 'AJAX', 'JAVA', 'PHP', 'POSTGRESQL', 'DHTML', 'HTML', 'JAVASCRIPT', 'JQUERY']
# ['ASP.NET', 'C#', 'JAVASCRIPT', 'JQUERY']
# ['C', 'C++']
# ['不拘']
# ['ASP.NET', 'C#', 'MYSQL', 'HTML']
# ['不拘']
# ['ASP.NET', 'JAVA']
# ['不拘']
# ['ASP.NET', 'C#', 'MYSQL', 'HTML']
# ['JAVA', 'ORACLE', 'PL/SQL']
# ['不拘']
# ['不拘']
# ['不拘']
# ['ANDROID', 'C', 'C++', 'JAVA']
# ['不拘']
# ['C#', 'JAVA', 'VISUAL C#', 'VISUAL STUDIO .NET', 'MS SQL', 'ORACLE', '鼎基 ERP']
# ['不拘']
# ['C#', 'POWERBUILDER', 'VISUAL BASIC']
# ['JAVA', 'JSP', 'MS SQL', 'TOMCAT', 'JAVASCRIPT']
# ['不拘']
# ['APPLE', 'MAC OS', 'MAC/MACINTOSH', 'IOS', 'OBJECTIVE-C', 'SWIFT']
# ['C#', 'C++', 'C++.NET', 'JAVA']
# ['不拘']
# ['C#', 'C++', 'JAVA', 'PYTHON', 'OBJECTIVE-C', 'EXCEL', 'POWERPOINT', 'WORD', 'TESTDIRECTOR', 'MICROSTRATEGY', 'PEOPLESOFT', 'SAS', 'TIBCO']
# ['不拘']
# ['不拘']
# ['DOS', 'LINUX', 'NOVELL', 'UNIX', 'WINDOWS 2000', 'WINDOWS 98', 'WINDOWS NT', 'C', 'C++', 'JAVA', 'PERL', 'VISUAL C++', 'DBASE', 'ORACLE', 'EXCEL', 'OUTLOOK', 'POWERPOINT', 'WORD', 'ASSEMBLY']
# ['WINDOWS 2000', 'C', 'C++', 'MFC', 'VISUAL STUDIO', 'XML', 'OUTLOOK', 'POWERPOINT', 'PROJECT', 'WORD', '中文打字20~50', '英文打字20~50']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['LINUX', 'MAC/MACINTOSH', 'WINDOWS 7', 'ANDROID', 'IOS']
# ['LINUX', 'C', 'C++']
# ['LINUX', 'WINDOWS 7', 'WINDOWS 8', 'C', 'C++', 'CGI', 'VISUAL C++', 'RTSP']
# ['EXCEL', 'POWERPOINT', 'PROJECT']
# ['WINDOWS SERVER 2008', 'AJAX', 'ASP.NET', 'C#', 'MS SQL', 'MYSQL', 'JQUERY']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['LINUX', 'ANDROID', 'C', 'C++', 'JAVA']
# ['不拘聯絡人：']
# ['不拘']
# ['APPLE', 'MAC OS', 'MAC/MACINTOSH', 'WINDOWS MOBILE', 'ANDROID', 'IOS']
# ['不拘']
# ['不拘']
# ['不拘']
# ['LINUX', 'PYTHON', 'MYSQL', 'HTML', 'JAVASCRIPT', 'JQUERY']
# ['不拘']
# ['不拘']
# ['不拘']
# ['WINDOWS 7', 'WINDOWS 8', 'WINDOWS SERVER 2012', 'DB2', '鼎新']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['C', 'C#', 'C++.NET', 'VISUAL BASIC .NET', 'VISUAL C#', 'VISUAL C++']
# ['C', 'C#', 'C++.NET', 'VISUAL BASIC .NET', 'VISUAL C#', 'VISUAL C++']
# ['AJAX', 'PHP', 'DREAMWEAVER', 'HTML', 'JAVASCRIPT']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['PROJECT']
# ['不拘']
# ['MS SQL', 'MYSQL', 'ORACLE']
# ['不拘']
# ['EXCEL', 'POWERPOINT', 'PROJECT', 'VISIO', 'WORD', 'ARCGIS', 'GIS']
# ['EXCEL', 'POWERPOINT', 'PROJECT', 'VISIO', 'WORD', 'ARCGIS', 'GIS']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['C', 'C++', 'C++.NET', 'JAVA', 'DATABASE ADMINISTRATOR', 'DATABASE MANAGEMENT', 'J2EE']
# ['ASP.NET', 'C++.NET', 'JAVA', 'VISUAL BASIC .NET', 'VISUAL STUDIO .NET', 'JAVASCRIPT']
# ['不拘']
# ['不拘']
# ['不拘']
# ['C++', 'JAVA']
# ['C#', 'C++', 'JAVA', 'OBJECTIVE-C', 'SWIFT']
# ['LINUX', 'MCU', 'C++']
# ['PL/SQL', 'EXCEL', 'POWERPOINT', 'WORD', 'SAP', '鼎新', '鼎基 ERP']
# ['不拘']
# ['JAVA', 'MS SQL', 'MYSQL']
# ['不拘']
# ['JAVA', 'SPRING']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['C#', 'MS SQL']
# ['不拘']
# ['不拘']
# ['C++.NET']
# ['不拘']
# ['不拘']
# ['ANDROID', 'C', 'C++']
# ['不拘']
# ['不拘']
# ['不拘']
# ['WINDOWS MOBILE', 'ANDROID', 'IOS', 'C', 'C++', 'JAVA', 'OBJECTIVE-C']
# ['不拘']
# ['PHP', 'MYSQL', 'HTML', 'JAVASCRIPT', 'JQUERY']
# ['PHP', 'MYSQL', 'HTML', 'JAVASCRIPT', 'JQUERY']
# ['HTML', 'JAVASCRIPT']
# ['ASP.NET', 'C#', 'MS SQL', 'MYSQL']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['C#', 'C++', 'C++.NET', 'VISUAL BASIC .NET', 'VISUAL C#', 'VISUAL C++', 'VISUAL J#', 'VISUAL J++', 'VISUAL STUDIO .NET', 'SILVERLIGHT']
# ['鼎新', '正航']
# ['MS SQL']
# ['不拘']
# ['不拘']
# ['不拘']
# ['LINUX', 'OOAD', 'OOP', 'SYSTEMS ANALYSIS', 'UML', 'AJAX', 'JAVA', 'JMS', 'JSP', 'SPRING', 'XSL', 'XSLT', 'DATA MODELING', 'DB2', 'JDBC', 'MYSQL', 'ODBC', 'ORACLE', 'TOMCAT', 'VMWARE', 'DHTML', 'J2EE', 'J2SE', 'JAVASCRIPT', 'XML WEB SERVICES', 'HTTP', 'LDAP', 'TCP/IP', 'JUNIT']
# ['不拘']
# ['不拘']
# ['不拘']
# ['OBJECTIVE-C', 'SWIFT']
# ['C#', 'VISUAL STUDIO .NET', 'MS SQL']
# ['不拘']
# ['不拘']
# ['OOAD', 'JAVA', 'JMS', 'SPRING', 'STRUTS']
# ['C', 'C++']
# ['不拘']
# ['不拘']
# ['LINUX', 'JAVA', 'SPRING', 'MYSQL']
# ['LINUX', 'JAVA', 'SPRING', 'MYSQL', 'ORACLE', 'J2EE']
# ['不拘']
# ['ASP', 'ASP.NET', 'C#', 'C++.NET', 'MYSQL', 'ORACLE']
# ['LINUX', 'C', 'C++', 'JSF', 'JSP', 'PYTHON', 'JDBC', 'ODBC', 'RDBMS', 'HTTP']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['ANDROID', 'ASP.NET', 'MS SQL', 'ORACLE']
# ['不拘']
# ['C#', 'HTML']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['SAP']
# ['不拘']
# ['不拘']
# ['ASP.NET', 'MS SQL', 'JQUERY', 'SAP']
# ['LINUX', 'ASP.NET', 'PHP']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['C++']
# ['不拘']
# ['AJAX', 'ASP.NET', 'C#', 'MS SQL', 'JAVASCRIPT']
# ['EXCEL', 'OUTLOOK', 'POWERPOINT', 'WORD']
# ['不拘']
# ['UML', 'DREAMWEAVER', 'HTML', 'EXCEL', 'POWERPOINT', 'PROJECT', 'VISIO', 'WORD']
# ['AJAX', 'ASP.NET', 'C#', 'PHP', 'MYSQL', 'DHTML', 'DREAMWEAVER', 'JAVASCRIPT', 'XML', 'JQUERY']
# ['SYSTEMS ANALYSIS', 'JAVA']
# ['AJAX', 'HTML', 'JAVASCRIPT', 'JQUERY', 'ADOBE PHOTOSHOP', 'ILLUSTRATOR']
# ['不拘']
# ['不拘']
# ['不拘']
# ['EXCEL', 'POWERPOINT', 'WORD']
# ['ASP.NET', 'C#']
# ['OOP', 'SYSTEMS ANALYST']
# ['ASP.NET', 'C#', 'VISUAL BASIC', 'VISUAL C#', 'VISUAL STUDIO .NET', 'ACCESS', 'MS SQL', 'VISUAL FOXPRO', 'EXCEL', 'WORD']
# ['不拘']
# ['ANDROID', 'WINDOWS 8', 'C', 'JAVA']
# ['不拘']
# ['不拘']
# ['MS SQL', 'MYSQL', 'ORACLE', 'TERADATA']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['ORACLE FORMS', 'DEVELOPER/ DESIGNER 2000']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['JAVA', 'SAP']
# ['不拘']
# ['不拘']
# ['不拘']
# ['OBJECTIVE-C']
# ['LINUX', 'UNIX', 'WINDOWS 8', 'ACCESS', 'TCP/IP', 'EXCEL', 'OUTLOOK', 'POWERPOINT', 'VISIO', 'WORD']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['DOS', 'WINDOWS 8', 'C#', 'C++.NET']
# ['不拘']
# ['WINDOWS SERVER 2008', 'ASP.NET', 'MS SQL', 'DHTML', 'HTML', 'JAVASCRIPT', 'JQUERY', 'IIS', 'EXCEL', 'OUTLOOK', 'POWERPOINT', 'WORD']
# ['SPRING', 'POSTGRESQL']
# ['SHELL', 'PERL', 'TCL']
# ['不拘']
# ['不拘']
# ['ORACLE', '鼎新']
# ['不拘']
# ['LINUX', 'MAC OS', 'ANDROID', 'IOS', 'C', 'C++', 'JAVASCRIPT', 'TCP/IP', 'PROJECT']
# ['不拘']
# ['不拘']
# ['ANDROID', 'ASP.NET', 'JAVA', 'PHP', 'VISUAL STUDIO .NET', 'OBJECTIVE-C', 'DHTML', 'HTML', 'SOAP']
# ['LINUX', 'ANDROID']
# ['不拘']
# ['不拘']
# ['不拘']
# ['WINDOWS XP', 'EXCEL', 'OUTLOOK', 'POWERPOINT', 'WORD']
# ['EXCEL', 'OUTLOOK', 'POWERPOINT', 'PROJECT', 'WORD']
# ['不拘']
# ['MCU', 'C', 'ARM']
# ['不拘']
# ['不拘']
# ['ASP.NET', 'C#', 'JAVA', 'ACCESS', 'MS SQL', 'EXCEL', 'POWERPOINT', 'WORD']
# ['ASP.NET', 'C#', 'JAVA', 'ACCESS', 'MS SQL', 'EXCEL', 'POWERPOINT', 'WORD']
# ['不拘']
# ['不拘']
# ['IOS', 'JAVA', 'PYTHON', 'OBJECTIVE-C', 'SWIFT', 'DATABASE ADMINISTRATOR', 'DATABASE MANAGEMENT', 'JAVASCRIPT', 'WEB MASTER/DEVELOPER']
# ['LINUX', 'ANDROID', 'IOS', 'C', 'C++']
# ['EXCEL', 'POWERPOINT', 'PROJECT', 'WORD']
# ['ACCESS', 'EXCEL', 'POWERPOINT', 'VISIO', 'WORD']
# ['不拘']
# ['C#']
# ['C', 'C++']
# ['EXCEL', 'POWERPOINT', 'WORD']
# ['EXCEL', 'POWERPOINT', 'WORD']
# ['EXCEL', 'POWERPOINT', 'WORD']
# ['EXCEL', 'POWERPOINT', 'WORD']
# ['SYSTEMS ANALYSIS', 'C']
# ['不拘']
# ['C#', 'C++', 'JAVA']
# ['C', 'C++']
# ['不拘']
# ['不拘']
# ['JAVA', 'PYTHON']
# ['不拘']
# ['不拘']
# ['不拘']
# ['LINUX', 'JAVA']
# ['不拘']
# ['MS SQL', 'PL/SQL', 'SAP']
# ['ETL', 'MS SQL', 'ORACLE', 'TERADATA']
# ['LINUX', 'UNIX', 'ETL', 'MS SQL', 'TERADATA']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['PYTHON', 'DHTML', 'HTML', 'JAVASCRIPT']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['C', 'C#', 'C++', 'JAVA']
# ['C', 'C#', 'C++', 'JAVA']
# ['C', 'C#', 'C++', 'JAVA', 'HTML', 'JQUERY']
# ['EXCEL', 'POWERPOINT', 'WORD']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘聯絡人：']
# ['不拘']
# ['C#', 'JAVA', 'VISUAL BASIC .NET', 'ORACLE', 'JAVASCRIPT']
# ['ASP.NET', 'C#', 'JAVA', 'JSP', 'MYSQL', 'ORACLE', 'PL/SQL', 'WEBLOGIC']
# ['LINUX', 'MAC OS', 'SHELL', 'UNIX', 'VMS', 'WINDOWS 2000', 'WINDOWS 2003', 'WINDOWS 95', 'WINDOWS 98', 'WINDOWS MOBILE', 'WINDOWS NT', 'WINDOWS VISTA', 'WINDOWS XP', 'WINDOWS 7', 'WINDOWS SERVER 2008', 'WINDOWS 8', 'WINDOWS SERVER 2012', 'SYSTEMS ADMINISTRATION', 'SYSTEMS ANALYSIS', 'DB2', 'MS SQL', 'MYSQL', 'ORACLE', 'PL/SQL', 'CITRIX', 'VMWARE', 'CISCO', 'ETHERNET', 'FIREWALL', 'FTP', 'HTTP', 'IIS', 'LAN', 'TCP/IP', 'VLAN', 'VPN', 'WAN']
# ['EXCEL', 'POWERPOINT', 'WORD']
# ['不拘']
# ['C', 'C++', 'EXCEL', 'POWERPOINT', 'PROJECT', 'WORD']
# ['不拘']
# ['ASP', 'ASP.NET', 'C#', 'VISUAL BASIC', 'VISUAL BASIC .NET', 'VISUAL C#', 'VISUAL STUDIO', 'VISUAL STUDIO .NET', 'MS SQL', 'JAVASCRIPT']
# ['LINUX', 'OOP', 'SYSTEMS ANALYSIS', 'JAVA', 'JAVASCRIPT', 'XML WEB SERVICES']
# ['LINUX', 'C#', 'MFC']
# ['不拘']
# ['ASP.NET', 'C#']
# ['不拘']
# ['不拘']
# ['POWERPOINT', 'WORD']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['LINUX', 'ANDROID', 'MCU', 'OOP', 'C', 'C#', 'C++', 'C++.NET', 'JAVA', 'CITRIX', 'MICROSOFT EXCHANGE', 'MICROSOFT SHAREPOINT', 'TOMCAT', 'VMWARE', 'WEBLOGIC', 'CISCO', 'DHCP', 'DNS', 'ETHERNET', 'FIREWALL', 'FTP', 'HTTP', 'HUBS/ ROUTERS', 'SECURITY', 'TCP/IP']
# ['LINUX', 'ANDROID', 'MCU', 'OOP', 'C', 'C#', 'C++', 'C++.NET', 'JAVA', 'CITRIX', 'MICROSOFT EXCHANGE', 'MICROSOFT SHAREPOINT', 'TOMCAT', 'VMWARE', 'WEBLOGIC', 'CISCO', 'DHCP', 'DNS', 'ETHERNET', 'FIREWALL', 'FTP', 'HTTP', 'HUBS/ ROUTERS', 'SECURITY', 'TCP/IP']
# ['LINUX', 'ANDROID', 'MCU', 'OOP', 'C', 'C#', 'C++', 'C++.NET', 'JAVA', 'CITRIX', 'MICROSOFT EXCHANGE', 'MICROSOFT SHAREPOINT', 'TOMCAT', 'VMWARE', 'WEBLOGIC', 'CISCO', 'DHCP', 'DNS', 'ETHERNET', 'FIREWALL', 'FTP', 'HTTP', 'HUBS/ ROUTERS', 'SECURITY', 'TCP/IP']
# ['APPLE', 'LINUX', 'MAC OS', 'NDS/NOVELL DIRECTORY SERVICES', 'UNIX', 'WIN CE', 'ANDROID', 'MCU', 'OOP', 'VXWORKS', 'C', 'C#', 'C++', 'C++.NET', 'JAVA', 'VISUAL C#', 'VISUAL C++', 'VISUAL J#', 'VISUAL J++', 'VISUAL STUDIO', 'VISUAL STUDIO .NET', 'CITRIX', 'MICROSOFT EXCHANGE', 'MICROSOFT SHAREPOINT', 'TOMCAT', 'VMWARE', 'WEBLOGIC', 'CHECKPOINT', 'CISCO', 'DHCP', 'DNS', 'ETHERNET', 'FIREWALL', 'FRAME RELAY', 'FTP', 'HTTP', 'HUBS/ ROUTERS', 'LAN', 'LDAP', 'MPLS', 'MULTINET', 'PPPOE', 'ROUTERS', 'SECURITY', 'SSH', 'TCP/IP', 'UDP', 'VLAN', 'VPN', 'WAN']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['PHP', 'MYSQL']
# ['C', 'C++', 'VISUAL C++', 'EXCEL', 'POWERPOINT', 'WORD']
# ['PHP', 'MYSQL']
# ['不拘']
# ['不拘']
# ['不拘']
# ['LINUX', 'JAVA', 'MYSQL', 'HTML', 'JAVASCRIPT', 'JQUERY']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['BIZTALK', 'WEBMETHODS', 'JAVASCRIPT']
# ['不拘']
# ['LINUX', 'JAVA', 'PHP', 'JAVASCRIPT', 'XML', 'EXCEL', 'OUTLOOK', 'POWERPOINT', 'PROJECT', 'WORD']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['JAVA', 'JSP', 'SPRING', 'STRUTS', 'MYSQL', 'ORACLE', 'DHTML', 'HTML', 'JAVASCRIPT', 'JQUERY']
# ['JAVA', 'JSP', 'MS SQL', 'ORACLE', 'DHTML', 'HTML', 'JAVASCRIPT', 'JQUERY']
# ['JAVA', 'JSP', 'SPRING', 'STRUTS', 'MYSQL', 'ORACLE', 'DHTML', 'HTML', 'JAVASCRIPT', 'JQUERY']
# ['SPRING', 'STRUTS', 'MYSQL', 'ORACLE', 'DHTML']
# ['不拘']
# ['ANDROID', 'IOS', 'ACCESS', 'EXCEL', 'OUTLOOK', 'PROJECT', 'WORD']
# ['LINUX', 'JAVA', 'SPRING', 'STRUTS', 'TOMCAT', 'JQUERY']
# ['不拘']
# ['不拘']
# ['SYSTEMS ANALYST', 'ASP', 'ASP.NET', 'C#', 'JAVA', 'MS SQL', 'ODBC', 'RDBMS', 'VMWARE', 'JAVASCRIPT', 'NETOBJECTS FUSION']
# ['ASP.NET', 'C#']
# ['LINUX', 'OS X', 'WINDOWS 2003', 'WINDOWS SERVER 2008', 'ANDROID', 'IOS', 'WINDOWS SERVER 2012', 'OOP', 'SYSTEMS ANALYSIS', 'SYSTEMS ANALYST', 'UML', 'C#', 'JAVA', 'PHP', 'VISUAL C#', 'MS SQL', 'MYSQL', 'J2EE', 'J2SE', 'JAVASCRIPT', 'XML', 'XML WEB SERVICES', 'JQUERY', 'FTP', 'HTTP', 'IIS', 'PROJECT', 'VISIO']
# ['C', 'C++']
# ['不拘']
# ['C', 'C++']
# ['不拘']
# ['不拘']
# ['不拘']
# ['MS SQL', 'HTML', 'JAVASCRIPT']
# ['ASP.NET', 'MS SQL', 'HTML', 'JAVASCRIPT']
# ['LINUX', 'WIN CE', 'ANDROID', 'IOS', 'C', 'C++']
# ['不拘']
# ['不拘']
# ['不拘']
# ['ASP', 'ASP.NET', 'JSP', 'PHP', 'MYSQL', 'ORACLE', 'POSTGRESQL', 'RDBMS', 'HTML', 'JAVASCRIPT', 'JQUERY']
# ['ASP', 'ASP.NET', 'JSP', 'PHP', 'MYSQL', 'ORACLE', 'POSTGRESQL', 'RDBMS', 'HTML', 'JAVASCRIPT', 'JQUERY']
# ['不拘']
# ['不拘']
# ['LINUX', 'UNIX']
# ['不拘']
# ['不拘']
# ['POWERPOINT', 'VISIO', 'NAVISION', 'ORACLE ERP', 'SAP', '鼎新', '正航']
# ['C', 'JAVA']
# ['不拘']
# ['IOS', 'SWIFT']
# ['AJAX', 'ASP.NET', 'C#', 'VISUAL STUDIO .NET', 'MS SQL', 'JQUERY']
# ['JAVA', 'MS SQL', 'JQUERY']
# ['LINUX', 'C', 'JAVA']
# ['不拘']
# ['ASP.NET', 'C#']
# ['不拘']
# ['EXCEL', 'POWERPOINT', 'WORD']
# ['POWERPOINT', 'PROJECT', 'VISIO', 'WORD']
# ['不拘']
# ['MCU', 'C', 'C++']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['ARM', 'FIRMWARE']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['ORACLE', 'SAP']
# ['不拘']
# ['C', 'JAVA']
# ['RUBY']
# ['WINDOWS VISTA', 'WINDOWS XP', 'ORACLE FORMS', 'MYSQL', 'POWERPOINT']
# ['PROJECT']
# ['JAVA']
# ['不拘']
# ['不拘']
# ['不拘']
# ['C', 'C++', 'JAVA', 'JSP', 'HTML', 'J2EE', 'J2SE', 'JAVASCRIPT']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['ASP.NET', 'C#']
# ['C', 'C#', 'C++', 'VISUAL C#', 'VISUAL C++']
# ['不拘']
# ['不拘']
# ['不拘']
# ['MS SQL', 'POSTGRESQL']
# ['不拘']
# ['ANDROID', 'IOS']
# ['不拘']
# ['MAC OS', 'ANDROID', 'IOS', 'HTML', 'JAVASCRIPT']
# ['EXCEL', 'INTERNET EXPLORER', 'OUTLOOK', 'WORD', '中文打字20~50', '英文打字20~50']
# ['ASP.NET', 'C#', 'VISUAL STUDIO', 'HTML', 'JAVASCRIPT', 'JQUERY']
# ['ASP.NET', 'C#', 'DATABASE ADMINISTRATOR', 'MS SQL', 'JAVASCRIPT', 'JQUERY']
# ['MS SQL', 'ORACLE', 'EXCEL', 'WORD', '鼎新']
# ['JAVA', 'JAVASCRIPT']
# ['LINUX', 'PHP']
# ['LINUX', 'C++', 'PHP']
# ['LINUX', 'C++', 'PHP']
# ['LINUX', 'JAVA', 'RMI', 'SPRING', 'STRUTS', 'JDBC', 'ORACLE', 'TOMCAT', 'EJB']
# ['不拘']
# ['LINUX', 'UNIX', 'C', 'C++', 'CGI', 'JAVA']
# ['不拘']
# ['LINUX', 'ANDROID', 'C', 'C++', 'JAVA', 'PERL', 'RUBY', 'MS SQL', 'HTML']
# ['ANDROID', 'C', 'C++', 'JAVA', 'PERL', 'VISUAL STUDIO', 'MS SQL', 'HTML']
# ['不拘']
# ['不拘']
# ['ABAQUS', 'DDK', 'MCU', 'OOAD', 'OOP', 'ORACLE FORMS', 'SDLC', 'SERVLETS', 'STL', 'SYSTEMS ADMINISTRATION', 'SYSTEMS ANALYSIS', 'SYSTEMS ANALYST', 'UML', 'VXWORKS', 'A+', 'ADA', 'ASP', 'C++', 'C++.NET', 'CGI', 'COM/DCOM', 'DEVELOPER/ DESIGNER 2000', 'JAVA']
# ['RUBY']
# ['ASP.NET', 'C#', 'JSP', 'VISUAL C#', 'VISUAL STUDIO .NET', 'HTML']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['WINDOWS SERVER 2008', 'ANDROID', 'IOS', 'WINDOWS SERVER 2012', 'AJAX', 'ASP.NET', 'VISUAL BASIC .NET', 'VISUAL C#', 'VISUAL STUDIO .NET', 'MS SQL', 'ODBC', 'ORACLE', 'POSTGRESQL', 'ARCGIS', 'ARCVIEW', 'GIS', 'MAPINFO']
# ['JAVA', 'HTML']
# ['C#', 'VISUAL STUDIO', 'WINFORM', 'MS SQL', 'ORACLE']
# ['C#', 'VISUAL STUDIO', 'WINFORM', 'MS SQL', 'ORACLE']
# ['不拘']
# ['ORACLE ERP', '鼎新']
# ['不拘']
# ['不拘']
# ['不拘']
# ['LINUX', 'WINDOWS XP', 'ASP.NET', 'JAVA', 'VISUAL BASIC', 'MS SQL', 'EXCEL', 'OUTLOOK', 'POWERPOINT', 'WORD']
# ['不拘']
# ['PHP']
# ['AIX', 'JAVA', 'JAVASCRIPT', '中文打字50~75', '英文打字50~75']
# ['不拘']
# ['不拘']
# ['WINDOWS SERVER 2008', 'WINDOWS SERVER 2012', 'ASP.NET', 'C#', 'MS SQL', 'MYSQL', 'ORACLE', 'VMWARE']
# ['不拘']
# ['LINUX', 'SOLARIS', 'UNIX', 'WINDOWS SERVER 2012', 'OOAD', 'UML', 'AJAX', 'JAVA', 'JSF', 'SPRING', 'MS SQL', 'ORACLE']
# ['IOS', 'OBJECTIVE-C', 'SWIFT']
# ['IOS', 'OBJECTIVE-C', 'SWIFT']
# ['ASP', 'ASP.NET', 'PHP']
# ['ASP', 'ASP.NET', 'PHP', 'VISUAL STUDIO .NET']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['JAVA']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['C#', 'C++.NET', 'JAVA']
# ['WINDOWS 2003', 'WINDOWS SERVER 2008', 'DATA MODELING', 'MS SQL', 'ODBC', 'ORACLE', 'RDBMS']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['SDLC']
# ['不拘']
# ['LINUX', 'ANDROID', 'C', 'C++', 'JAVA', 'PYTHON']
# ['不拘']
# ['不拘']
# ['C++', 'C++.NET', 'JAVA', 'PYTHON', 'AFTER EFFECTS', 'PREMIERE', 'VEGAS']
# ['C++']
# ['ANDROID', 'OOP', 'JAVA']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['WINDOWS XP', 'WINDOWS 7', 'EXCEL', 'POWERPOINT', 'WORD']
# ['不拘']
# ['不拘']
# ['LINUX', 'C', 'C++']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['AIX', 'UNIX', 'JAVA', 'ODBC', 'TOMCAT', 'HTML', 'JAVASCRIPT', 'XML']
# ['LINUX', 'WINDOWS SERVER 2008', 'JAVA', 'VISUAL C#', 'RDBMS']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['UNITY3D']
# ['不拘']
# ['C', 'C++', 'DELPHI', 'ARM', 'CPLD', 'EMC/EMI', 'FIRMWARE', 'PROTEL']
# ['JAVA', 'PHP', 'MYSQL', 'HTML', 'JAVASCRIPT', 'JQUERY']
# ['LINUX', 'ANDROID', 'IOS', 'C#', 'JAVA', 'MFC', 'SWIFT']
# ['不拘']
# ['WINDOWS 2000', 'WINDOWS XP', 'EXCEL', 'INTERNET EXPLORER', 'OUTLOOK', 'POWERPOINT', 'WORD', '中文打字50~75']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['EXCEL', 'POWERPOINT', 'PROJECT', 'VISIO', 'WORD', 'GIS']
# ['不拘']
# ['不拘']
# ['不拘']
# ['SAP']
# ['C++', 'VISUAL C++']
# ['C++', 'JAVA', 'JAVASCRIPT']
# ['不拘']
# ['不拘']
# ['不拘']
# ['C#', 'C++', 'MS SQL', 'MYSQL']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['FREEBSD', 'LINUX', 'WINDOWS 2000', 'C', 'C++', 'JAVA', 'PHP', 'PYTHON', 'MYSQL', 'JAVASCRIPT', 'CVS']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['AJAX', 'ASP.NET', 'C#', 'PHP', 'MS SQL', 'MYSQL']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['C', 'C++', 'MATLAB', 'PYTHON', 'R']
# ['不拘']
# ['不拘']
# ['不拘']
# ['C++', 'VISUAL C++']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['EXCEL', 'INTERNET EXPLORER', 'OUTLOOK', 'POWERPOINT', 'WORD']
# ['AJAX', 'ASP', 'C', 'C++', 'CGI', 'JAVA', 'MFC', 'OBJECTIVE-C']
# ['OOP', 'JAVA', 'VISUAL BASIC .NET', 'VISUAL C#', 'MS SQL', 'ORACLE']
# ['OOP', 'JAVA', 'VISUAL BASIC .NET', 'VISUAL C#', 'MS SQL', 'ORACLE']
# ['不拘']
# ['不拘']
# ['OOAD', 'JAVA', 'SPRING']
# ['OOAD', 'JAVA', 'SPRING', 'STRUTS']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['C', 'C++', 'ASSEMBLY']
# ['HTML', 'JAVASCRIPT聯絡人：']
# ['C', 'C++']
# ['C', 'C++']
# ['C', 'C#', 'C++']
# ['SERVLETS', 'AJAX', 'JAVA', 'JSP', 'STRUTS', 'MS SQL', 'ORACLE', 'HTML', 'JAVASCRIPT', 'XML']
# ['不拘']
# ['不拘']
# ['不拘']
# ['C#', 'C++', 'JAVA', 'PYTHON']
# ['C#', 'C++', 'JAVA', 'PYTHON']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['不拘']
# ['SIEBEL', 'ORACLE ERP', 'SAP']
# ['不拘']

# %%
import re
count_list = []
for work in datas['job_lists']:
    count_list.extend(re.findall('([\x00-\x7F]+)', work['tools']))

count_list
# Out:
# ['Linux',
#  'Java',
#  'Spring',
#  'Struts',
#  'Tomcat',
#  'jQuery',
#  'PHP',
#  'PHP',
#  'C',
#  'C#',
#  'PHP',
#  'Visual Basic',
#  'MySQL',
#  'HTML',
#  'JavaScript',
#  'jQuery',
#  'C',
#  'C#',
#  'PHP',
#  'Visual Basic',
#  'MySQL',
#  'HTML',
#  'JavaScript',
#  'jQuery',
#  'Linux',
#  'Android',
#  'Java',
#  'MySQL',
#  'PostgreSQL',
#  'Excel',
#  'PowerPoint',
#  'Visio',
#  'Word',
#  'C#',
#  'C++',
#  'Unity3D',
#  'ASP.NET',
#  'MS SQL',
#  'ASP.NET',
#  'MS SQL',
#  'Linux',
#  'Mac OS',
#  'Windows 7',
#  'AJAX',
#  'C++',
#  'Java',
#  'PHP',
#  'MySQL',
#  'HTML',
#  'JavaScript',
#  'XML',
#  'FTP',
#  'HTTP',
#  'TCP/IP',
#  'Excel',
#  'PowerPoint',
#  'C',
#  'C++',
#  'Java',
#  'PHP',
#  'Visual Studio',
#  'MS SQL',
#  'MySQL',
#  'JavaScript',
#  'XHTML',
#  'XML',
#  'Linux',
#  'Shell',
#  'C',
#  'C++',
#  'Java',
#  'Perl',
#  'Python',
#  'JSP',
#  'ActiveX',
#  'HTML',
#  'jQuery',
#  'Socket',
#  'Linux',
#  'MCU',
#  'C',
#  'C++',
#  'ActionScript',
#  'C',
#  'C#',
#  'C++',
#  'C++.Net',
#  'Java',
#  'Objective-C',
#  'MS SQL',
#  'MySQL',
#  'HTML',
#  'JavaScript',
#  'XML Web services',
#  'HTTP',
#  'IIS',
#  'TCP/IP',
#  'C#',
#  'Java',
#  'Visual Basic .net',
#  'MySQL',
#  'Oracle',
#  'XML',
#  'jQuery',
#  'OOAD',
#  'Systems Analysis',
#  'UML',
#  'Data Modeling',
#  'Database Management',
#  'MS SQL',
#  'MySQL',
#  'LabVIEW',
#  'Excel',
#  'Outlook',
#  'PowerPoint',
#  'Word',
#  '20~50',
#  'Linux',
#  'UNIX',
#  'Windows Server 2008',
#  'OOAD',
#  'OOP',
#  'SDLC',
#  'Systems Analysis',
#  'AJAX',
#  'Java',
#  'JMS',
#  'JSF',
#  'JSP',
#  'Spring',
#  'Struts',
#  'Informix',
#  'JDBC',
#  'MS SQL',
#  'Oracle',
#  'PL/SQL',
#  'SYSBASE',
#  'Linux',
#  'UNIX',
#  'Windows Server 2008',
#  'OOAD',
#  'OOP',
#  'SDLC',
#  'Systems Analysis',
#  'UML',
#  'AJAX',
#  'Java',
#  'JMS',
#  'JSF',
#  'JSP',
#  'Spring',
#  'Struts',
#  'Informix',
#  'JDBC',
#  'MS SQL',
#  'Oracle',
#  'PL/SQL',
#  'SYSBASE',
#  'Linux',
#  'UNIX',
#  'Windows Server 2008',
#  'OOAD',
#  'OOP',
#  'SDLC',
#  'Systems Analysis',
#  'UML',
#  'Java',
#  'JMS',
#  'JSF',
#  'Spring',
#  'Struts',
#  'Informix',
#  'JDBC',
#  'MS SQL',
#  'Oracle',
#  'PL/SQL',
#  'SYSBASE',
#  'UNIX',
#  'Developer/ Designer 2000',
#  'OS/400',
#  'RPG',
#  'OS/400',
#  'UNIX',
#  'RPG',
#  'ASP.NET',
#  'C#',
#  'MS SQL',
#  'JavaScript',
#  'jQuery',
#  'Linux',
#  'Windows Server 2012',
#  'OOAD',
#  'OOP',
#  'Systems Analysis',
#  'UML',
#  'AJAX',
#  'ASP.NET',
#  'C',
#  'C#',
#  'C++',
#  'Visual C++',
#  'Visual Studio .net',
#  'MS SQL',
#  'Oracle',
#  'PostgreSQL',
#  'TCP/IP',
#  'PLC',
#  'ASP.NET',
#  'C#',
#  'iOS',
#  'Objective-C',
#  'C',
#  'C++',
#  'MFC',
#  'Ethernet',
#  'HTTP',
#  'Socket',
#  'TCP/IP',
#  'ARM',
#  'Assembly',
#  'Python',
#  'MySQL',
#  'HTML',
#  'JavaScript',
#  'TCP/IP',
#  'Linux',
#  'Java',
#  'Tomcat',
#  'Junit',
#  'Linux',
#  'Windows Server 2008',
#  'AJAX',
#  'ASP.NET',
#  'Java',
#  'Excel',
#  'Outlook',
#  'PowerPoint',
#  'Word',
#  'OOP',
#  'C++',
#  'Excel',
#  'Outlook',
#  'PowerPoint',
#  'Project',
#  'Visio',
#  'Word',
#  'Linux',
#  'Android',
#  'MCU',
#  'OOP',
#  'C',
#  'C#',
#  'C++',
#  'C++.Net',
#  'Java',
#  'Citrix',
#  'Microsoft Exchange',
#  'Microsoft SharePoint',
#  'Tomcat',
#  'Vmware',
#  'WebLogic',
#  'Cisco',
#  'DHCP',
#  'DNS',
#  'Ethernet',
#  'Firewall',
#  'FTP',
#  'HTTP',
#  'Hubs/ Routers',
#  'Security',
#  'TCP/IP',
#  'Linux',
#  'C++',
#  'Excel',
#  'PowerPoint',
#  'Project',
#  'Word',
#  'Excel',
#  'Outlook',
#  'PowerPoint',
#  'Word',
#  '20~50',
#  '20~50',
#  'Java',
#  'Objective-C',
#  'SWIFT',
#  'SAP',
#  'Linux',
#  'Mac OS',
#  'Android',
#  'iOS',
#  'Java',
#  'DOS',
#  'Windows Server 2012',
#  'MS SQL',
#  'SYSBASE',
#  'Excel',
#  'Internet Explorer',
#  'Outlook',
#  'Project',
#  'Word',
#  '50~75',
#  '50~75',
#  'AutoCAD',
#  'MicroStrategy',
#  'MRP',
#  'FreeBSD',
#  'Linux',
#  'Solaris',
#  'SUN OS',
#  'C++',
#  'Java',
#  'JSP',
#  'DB2',
#  'MS SQL',
#  'MySQL',
#  'Oracle',
#  'Dreamweaver',
#  'Fireworks',
#  'HTML',
#  'Flash',
#  'Adobe Photoshop',
#  'Illustrator',
#  'Linux',
#  'OOAD',
#  'OOP',
#  'Servlets',
#  'UML',
#  'Java',
#  'JSP',
#  'JDBC',
#  'MySQL',
#  'RDBMS',
#  'Tomcat',
#  'HTML',
#  'J2EE',
#  'J2SE',
#  'JavaScript',
#  'jQuery',
#  'C#',
#  'C++',
#  'Java',
#  'MS SQL',
#  'MySQL',
#  'Oracle',
#  'Sybase',
#  'UML',
#  'AJAX',
#  'ASP.NET',
#  'C++.Net',
#  'Java',
#  'JSP',
#  'PHP',
#  'MS SQL',
#  'MySQL',
#  'Oracle',
#  'Cold Fusion',
#  'JavaScript',
#  'XML',
#  'UML',
#  'Java',
#  'Objective-C',
#  'Java',
#  'Spring',
#  'Oracle',
#  'Tomcat',
#  'HTML',
#  'XML',
#  'jQuery',
#  'Java',
#  'Spring',
#  'Oracle',
#  'Tomcat',
#  'HTML',
#  'XML',
#  'jQuery',
#  'OOP',
#  'SDLC',
#  'UML',
#  'ASP.NET',
#  'Visual C#',
#  'MS SQL',
#  'Web Master/Developer',
#  'Excel',
#  'PowerPoint',
#  'Project',
#  'Visio',
#  'Word',
#  'ASP.NET',
#  'C#',
#  'HTML',
#  'JavaScript',
#  'IIS',
#  'C++',
#  'Linux',
#  'ADA',
#  'C',
#  'C++',
#  'Visual C++',
#  'Servlets',
#  'Java',
#  'JSP',
#  'MS SQL',
#  'Oracle',
#  'PL/SQL',
#  'JavaScript',
#  'XML',
#  'jQuery',
#  'Linux',
#  'C',
#  'C#',
#  'Java',
#  'TCP/IP',
#  'Linux',
#  'C',
#  'C#',
#  'Java',
#  'TCP/IP',
#  'C',
#  'Python',
#  'DirectX',
#  'Visual C#',
#  'Visual C++',
#  'Database Management',
#  'TCP/IP',
#  'UDP',
#  'RTSP',
#  'C',
#  'C++',
#  'CGI',
#  'Mac OS',
#  'Windows 2000',
#  'Windows NT',
#  'Windows XP',
#  'Excel',
#  'Outlook',
#  'PowerPoint',
#  'Word',
#  'C',
#  'C++',
#  'Visual Studio',
#  'Assembly',
#  'Visual Studio .net',
#  'MS SQL',
#  'DHTML',
#  'JavaScript',
#  'jQuery',
#  'C#',
#  'Java',
#  'Android',
#  'PHP',
#  'SWIFT',
#  'HTML',
#  'Android',
#  'Systems Analysis',
#  'Systems Analyst',
#  'UML',
#  'PHP',
#  'SWIFT',
#  'HTML',
#  'UML',
#  'C',
#  'Objective-C',
#  'UML',
#  'C',
#  'Java',
#  'J2SE',
#  'Linux',
#  'Android',
#  'C#',
#  'C++',
#  'MS SQL',
#  'C',
#  'C++',
#  'Linux',
#  'Systems Analysis',
#  'AJAX',
#  'Java',
#  'PHP',
#  'MySQL',
#  'HTML',
#  'JavaScript',
#  'jQuery',
#  'Linux',
#  'Systems Analysis',
#  'AJAX',
#  'Java',
#  'PHP',
#  'MySQL',
#  'PostgreSQL',
#  'HTML',
#  'JavaScript',
#  'jQuery',
#  'Data Modeling',
#  'Database Administrator',
#  'Database Management',
#  'DataStage',
#  'ETL',
#  'Informatica',
#  'Excel',
#  'Outlook',
#  'PowerPoint',
#  'Word',
#  'Excel',
#  'Outlook',
#  'PowerPoint',
#  'Word',
#  'Excel',
#  'Outlook',
#  'PowerPoint',
#  'Word',
#  'Linux',
#  'Mac OS',
#  'OS X',
#  'C#',
#  'C++',
#  'Java',
#  'MS SQL',
#  'MySQL',
#  'JavaScript',
#  'jQuery',
#  'FTP',
#  'HTTP',
#  'IIS',
#  'PowerPoint',
#  'Word',
#  'Linux',
#  'ASP.NET',
#  'Java',
#  'PHP',
#  'MS SQL',
#  'Oracle',
#  'Linux',
#  'ASP.NET',
#  'Java',
#  'PHP',
#  'MS SQL',
#  'Oracle',
#  'Linux',
#  'C',
#  'C++',
#  'Visual C++',
#  'TCP/IP',
#  'WLAN',
#  'C',
#  'C++',
#  'Visual C++',
#  'TCP/IP',
#  'ARM',
#  'Drivers',
#  'Firmware',
#  'MCU',
#  'C',
#  'C++',
#  'ARM',
#  'C',
#  'C++',
#  'OS X',
#  '50~75',
#  '50~75',
#  'HTTP',
#  'Socket',
#  'TCP/IP',
#  'Excel',
#  'PowerPoint',
#  'Word',
#  '20~50',
#  '20~50',
#  'HTTP',
#  'Socket',
#  'TCP/IP',
#  'Excel',
#  'PowerPoint',
#  'Word',
#  '20~50',
#  '20~50',
#  'HTTP',
#  'Socket',
#  'TCP/IP',
#  'Excel',
#  'PowerPoint',
#  'Word',
#  '20~50',
#  '20~50',
#  'Linux',
#  'C',
#  'C++',
#  'Java',
#  'JSP',
#  'Python',
#  'Ruby',
#  'C++',
#  'Java',
#  'Python',
#  'Database Management',
#  'OOAD',
#  'OOP',
#  'Systems Analysis',
#  'UML',
#  'Windows 7',
#  'Windows Server 2008',
#  'Android',
#  'iOS',
#  'Windows 8',
#  'Windows Server 2012',
#  'Java',
#  'Objective-C',
#  'IMS',
#  'HTTP',
#  'TCP/IP',
#  'Excel',
#  'Outlook',
#  'PowerPoint',
#  'Word',
#  'RTSP',
#  'JavaScript',
#  'PHP',
#  'MS SQL',
#  'MySQL',
#  'DHTML',
#  'HTML',
#  'JavaScript',
#  'jQuery',
#  'Dreamweaver',
#  'HTML',
#  'JavaScript',
#  'Android',
#  'Java',
#  'iOS',
#  'C++',
#  'Objective-C',
#  'SWIFT',
#  'ASP.NET',
#  'C#',
#  'C++.Net',
#  'DHTML',
#  'C++',
#  'JavaScript',
#  'Excel',
#  'Outlook',
#  'PowerPoint',
#  'Project',
#  'Word',
#  'ASP.NET',
#  'C#',
#  'MS SQL',
#  'Oracle',
#  'AJAX',
#  'ASP.NET',
#  'PHP',
#  'MySQL',
#  'Apache SOAP',
#  'HTML',
#  'JavaScript',
#  'jQuery',
#  'IIS',
#  'C',
#  'C++',
#  'AJAX',
#  'Java',
#  'Python',
#  'Ruby',
#  'Spring',
#  'C',
#  'C++',
#  'C#',
#  'C++.Net',
#  'Java',
#  'MS SQL',
#  'MySQL',
#  'Oracle',
#  'Excel',
#  'PowerPoint',
#  'Project',
#  'Word',
#  'Excel',
#  'PowerPoint',
#  'Project',
#  'Word',
#  'Excel',
#  'Outlook',
#  'PowerPoint',
#  'Project',
#  'Visio',
#  'Word',
#  'Linux',
#  'AJAX',
#  'Java',
#  'JSP',
#  'Spring',
#  'Struts',
#  'MySQL',
#  'Oracle',
#  'Tomcat',
#  'JavaScript',
#  'jQuery',
#  'Linux',
#  'AJAX',
#  'Java',
#  'JSF',
#  'JSP',
#  'Spring',
#  'Struts',
#  'MS SQL',
#  'MySQL',
#  'Oracle',
#  'Tomcat',
#  'Vmware',
#  'WebLogic',
#  'JavaScript',
#  'jQuery',
#  'AJAX',
#  'Java',
#  'MS SQL',
#  'MySQL',
#  'Oracle',
#  'HTML',
#  'JavaScript',
#  'jQuery',
#  'AJAX',
#  'Java',
#  'MS SQL',
#  'MySQL',
#  'Oracle',
#  'DHTML',
#  'HTML',
#  'J2EE',
#  'JavaScript',
#  'jQuery',
#  'ASP.NET',
#  'Java',
#  'PHP',
#  'Visual Basic',
#  'Visual Basic .net',
#  'Visual Studio',
#  'Visual Studio .net',
#  'ADO',
#  'MS SQL',
#  'ODBC',
#  'Oracle',
#  'HTML',
#  'JavaScript',
#  'VBScript',
#  'XML',
#  'OOP',
#  'STL',
#  'C++',
#  'Visual C++',
#  'Linux',
#  'C',
#  'C++',
#  'ASP.NET',
#  'C#',
#  'Visual Basic .net',
#  'Visual Studio .net',
#  'WinForm',
#  'MS SQL',
#  'DHTML',
#  'Dreamweaver',
#  'HTML',
#  'jQuery',
#  'ASP.NET',
#  'C#',
#  'WinForm',
#  'MS SQL',
#  'C++',
#  'Oracle Forms',
#  'Oracle',
#  'Cisco',
#  'Oracle Financials',
#  'Oracle ERP',
#  'Objective-C',
#  'SWIFT',
#  'Oracle ERP',
#  'SAP',
#  'C',
#  'C++',
#  'Java',
#  'Visual C++',
#  'C#',
#  'Visual Studio',
#  'JavaScript',
#  'Java',
#  'J2EE',
#  'JavaScript',
#  'AIX',
#  'Linux',
#  'Windows 7',
#  'Windows Server 2008',
#  'Systems Administration',
#  'Systems Analysis',
#  'Systems Analyst',
#  'C',
#  'Visual Basic .net',
#  'Visual Studio .net',
#  'Win32',
#  'MS SQL',
#  'Oracle',
#  'Tomcat',
#  'ActiveX',
#  'HTML',
#  'XML',
#  'Excel',
#  'PowerPoint',
#  'Word',
#  'Windows 7',
#  'Windows 8',
#  'Linux',
#  'C++',
#  'PowerBuilder',
#  'Oracle',
#  'Java',
#  'JSP',
#  'Spring',
#  'Struts',
#  'MS SQL',
#  'MySQL',
#  'Oracle',
#  'C#',
#  'Java',
#  'JSP',
#  'Android',
#  'C',
#  'C++',
#  'Linux',
#  'C',
#  'C++',
#  'Perl',
#  'Python',
#  'HTML',
#  'JavaScript',
#  'Linux',
#  'AJAX',
#  'Java',
#  'Spring',
#  'Struts',
#  'MySQL',
#  'J2EE',
#  'jQuery',
#  'ASP.NET',
#  'C#',
#  'MS SQL',
#  'JavaScript',
#  'ASP.NET',
#  'C#',
#  'MS SQL',
#  'JavaScript',
#  'ASP.NET',
#  'C#',
#  'MS SQL',
#  'JavaScript',
#  'ASP.NET',
#  'C#',
#  'MS SQL',
#  'JavaScript',
#  'AJAX',
#  'HTML',
#  'JavaScript',
#  'jQuery',
#  'Shell',
#  'Java',
#  'PHP',
#  'Python',
#  'MySQL',
#  'Oracle',
#  'PostgreSQL',
#  'HTML',
#  'JavaScript',
#  'HTTP',
#  'ASP',
#  'C#',
#  'WinForm',
#  'C',
#  'C++',
#  'Unity3D',
#  'C',
#  'C#',
#  'C++',
#  'AJAX',
#  'ASP.NET',
#  'MS SQL',
#  'jQuery',
#  'Excel',
#  'PowerPoint',
#  'Project',
#  'Visio',
#  'Word',
#  'ASP.NET',
#  'Visual Basic .net',
#  'MS SQL',
#  'Oracle',
#  'Linux',
#  'Windows Server 2008',
#  'Java',
#  'Oracle',
#  'Vmware',
#  'HTML',
#  'Cisco',
#  'Juniper',
#  'Excel',
#  'Visio',
#  'SAN/NAS',
#  'VERITAS',
#  'C#',
#  'Java',
#  'Objective-C',
#  'SWIFT',
#  'HTML',
#  'JavaScript',
#  'Excel',
#  'PowerPoint',
#  'Word',
#  'ASP',
#  'ASP.NET',
#  'C#',
#  'PHP',
#  'Visual Studio',
#  'Visual Studio .net',
#  'MS SQL',
#  'MySQL',
#  'DHTML',
#  'HTML',
#  'JavaScript',
#  'XML',
#  'XML Web services',
#  'jQuery',
#  'C++',
#  'Python',
#  'C++',
#  'Python',
#  'C',
#  'C#',
#  'C++',
#  'FPGA',
#  'C#',
#  'Delphi',
#  'Java',
#  'C#',
#  'MS SQL',
#  'JavaScript',
#  'SAP',
#  'C#',
#  'Delphi',
#  'Java',
#  'C#',
#  'C++.Net',
#  'Oracle',
#  'Linux',
#  'Servlets',
#  'C',
#  'C++',
#  'Java',
#  'JDBC',
#  'DHTML',
#  'HTML',
#  'JavaScript',
#  'jQuery',
#  'C++',
#  'MFC',
#  'Visual C++',
#  'C++',
#  'C++.Net',
#  'MFC',
#  'Visual C++',
#  'C#',
#  'C++',
#  'C++.Net',
#  'Matlab',
#  'PHP',
#  'Python',
#  'Objective-C',
#  'C++',
#  'C++.Net',
#  'Visual Basic .net',
#  'Visual C++',
#  'C',
#  'C#',
#  'C++',
#  'Matlab',
#  'ASP.NET',
#  'C#',
#  'MS SQL',
#  'Java',
#  'C#',
#  'Java',
#  'Visual C#',
#  'Visual J#',
#  'Unity3D',
#  'OOAD',
#  'OOP',
#  'SDLC',
#  'Servlets',
#  'Systems Analyst',
#  'UML',
#  'AJAX',
#  'Java',
#  'JSP',
#  'Spring',
#  'Struts',
#  'Linux',
#  ...]

# %% [markdown]
# ## count

# %%
from collections import Counter

ct = Counter()
for word in count_list:
    word = word.strip().upper()
    ct[word] += 1

ct.most_common(20)
# Out:
# [('JAVA', 174),
#  ('C++', 131),
#  ('C#', 120),
#  ('MS SQL', 108),
#  ('C', 107),
#  ('LINUX', 105),
#  ('JAVASCRIPT', 97),
#  ('ASP.NET', 78),
#  ('HTML', 77),
#  ('WORD', 73),
#  ('EXCEL', 73),
#  ('ORACLE', 73),
#  ('POWERPOINT', 71),
#  ('MYSQL', 69),
#  ('JQUERY', 58),
#  ('PHP', 50),
#  ('ANDROID', 45),
#  ('AJAX', 39),
#  ('SPRING', 33),
#  ('OUTLOOK', 31)]

# %%
type(ct.most_common(20))
# Out:
# list

# %%
from collections import Counter
aaa = Counter()
bbb = Counter()

aaa['a'] = 1

bbb['a'] = 3

ccc = aaa + bbb
ccc
# Out:
# Counter({'a': 4})

# %% [markdown]
# # 104 ver0.1

# %%
import json
import re
from os import walk
from collections import Counter


#return a dict key:path value:filenames
def getFilesPath(path = './'):
    pathdict = {}
    for (dirpath, dirnames, filenames) in walk(path):
        for name in dirnames:
            nowpath = dirpath + '/'+ name
            pathlist.update(getFilesPath(nowpath))
        pathdict[dirpath] = filenames
        break
    return pathdict

def str2list(skills):
    skills_list = re.findall('([\x00-\x7F]+)', skills)

    return [word.strip().upper() for word in skills_list]


def list_for_all(jobs):
    count_list = []
    for work in jobs:
        count_list.extend( str2list(work['tools']))
    return count_list

def counting_tools(path):
    pathDict = getFilesPath(path)
    ct = Counter()
    ct['jobs_number'] = 0
    for key, value in pathDict.items():
        for filename in value:
            if '.json' in filename:
                filepath = key+'/'+filename
                with open(filepath, encoding = 'utf8') as f:
                    datas = json.load(f)
                    count_list = list_for_all(datas['job_lists'])
                    for word in count_list:
                        ct[word] += 1
                        ct['jobs_number'] += 1
    return ct


if __name__ == "__main__":
    path = './data/104'
    ct = counting_tools(path)

# %%
ct.most_common(31)
# Out:
# [('jobs_number', 69602),
#  ('JAVA', 3035),
#  ('MS SQL', 2961),
#  ('LINUX', 2847),
#  ('JAVASCRIPT', 2809),
#  ('C++', 2498),
#  ('C#', 2398),
#  ('HTML', 2264),
#  ('C', 2204),
#  ('EXCEL', 2110),
#  ('MYSQL', 2061),
#  ('WORD', 2048),
#  ('ASP.NET', 1872),
#  ('JQUERY', 1735),
#  ('POWERPOINT', 1622),
#  ('PHP', 1596),
#  ('ORACLE', 1422),
#  ('OUTLOOK', 1054),
#  ('AJAX', 903),
#  ('WINDOWS SERVER 2008', 889),
#  ('WINDOWS SERVER 2012', 850),
#  ('WINDOWS 7', 817),
#  ('TCP/IP', 795),
#  ('ANDROID', 706),
#  ('PYTHON', 685),
#  ('WINDOWS XP', 580),
#  ('JSP', 562),
#  ('VMWARE', 547),
#  ('VISUAL STUDIO .NET', 504),
#  ('HTTP', 503),
#  ('20~50', 500)]

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


ct_df = pd.DataFrame.from_dict(ct.most_common(31))

# %%
ct_df[1:ct_df.size]
# Out:
#                       0     1
# 1                  JAVA  3035
# 2                MS SQL  2961
# 3                 LINUX  2847
# 4            JAVASCRIPT  2809
# 5                   C++  2498
# 6                    C#  2398
# 7                  HTML  2264
# 8                     C  2204
# 9                 EXCEL  2110
# 10                MYSQL  2061
# 11                 WORD  2048
# 12              ASP.NET  1872
# 13               JQUERY  1735
# 14           POWERPOINT  1622
# 15                  PHP  1596
# 16               ORACLE  1422
# 17              OUTLOOK  1054
# 18                 AJAX   903
# 19  WINDOWS SERVER 2008   889
# 20  WINDOWS SERVER 2012   850
# 21            WINDOWS 7   817
# 22               TCP/IP   795
# 23              ANDROID   706
# 24               PYTHON   685
# 25           WINDOWS XP   580
# 26                  JSP   562
# 27               VMWARE   547
# 28   VISUAL STUDIO .NET   504
# 29                 HTTP   503
# 30                20~50   500

# %%
path = './data/1111'
getFilesPath(path)
# Out:
# {'./data/1111': ['1111_Get_C#_d0All.json',
#   '1111_Get_C++_d0All.json',
#   '1111_Get_C_d0All.json',
#   '1111_Get_HADOOP_d0All.json',
#   '1111_Get_HTML_d0All.json',
#   '1111_Get_JavaScript_d0All.json',
#   '1111_Get_Java_d0All.json',
#   '1111_Get_Linux_d0All.json',
#   '1111_Get_Mongo DB_d0All.json',
#   '1111_Get_PHP_d0All.json',
#   '1111_Get_PYTHON_d0All.json',
#   '1111_Get_SQL_d0All.json',
#   '1111_Get_大數據分析師_d0All.json',
#   '1111_Get_資料分析師_d0All.json',
#   '1111_Get_軟體設計工程師_d0All.json']}

# %%
filepath = './data/1111/1111_Get_軟體設計工程師_d0All.json'

with open(filepath, encoding = 'utf8') as f:
                    datas = json.load(f)

# %%
datas[0]
# Out:
# {'company': '全國公證檢驗股份有限公司',
#  'content': '*應用系統程式開發與維護*應用系統程式測試*應用系統程式文件撰寫*SQL Server 資料庫設定,資料庫排程設定、效能調整,資料庫問題處理',
#  'other_condition': '*熟悉 ASP.NET (VB.Net / C#.Net ) 與 SQL Server 資料庫程式設計*熟悉Windows 7*至少5年以上 ASP.NET 與 SQL Server 資料庫程式設計開發實務經驗*能夠獨立作業, 團隊合作, 並具有良好溝通能力',
#  'post_date': '2017/7/7',
#  'skills': 'ASP、VB.NET、C#.NET',
#  'title': ' .NET Programmer 程式開發人員 '}

# %%
str2list(datas[0]['skills'])
# Out:
# ['ASP', 'VB.NET', 'C#.NET']

# %%
import numpy as np
import pandas as pd

df = pd.read_json(filepath)

# %%
print(type(df['skills']))
df['skills']
# Out:
# <class 'pandas.core.series.Series'>
# 0                                       ASP、VB.NET、C#.NET
# 1                                   ASP.NET、MS SQL、Oracle
# 2       Java Script、jQuery、Illustrator、Adobe Photoshop...
# 3
# 4
# 5
# 6
# 7       Word、Excel、PowerPoint、ASP、Java Script、VB Scrip...
# 8       Word、Excel、PowerPoint、Outlook、Project、Windows ...
# 9
# 10
# 11                                         ASP.NET、MS SQL
# 12                                 JAVA、C#.NET、PHP、Python
# 13
# 14               JAVA、Visual C++、VB.NET、OOP、MS SQL、Oracle
# 15
# 16
# 17
# 18
# 19
# 20                                    C/C++、C#.NET、Oracle
# 21
# 22
# 23      Word、Excel、PowerPoint、Outlook、DOS、LINUX、Window...
# 24
# 25                                         ASP.NET、C#.NET
# 26
# 27
# 28                                  MCU、VHDL、Verilog、FPGA
# 29
#                               ...
# 2794              PowerBuilder、PL/SQL、MySQL、Oracle、SyBase
# 2795
# 2796
# 2797
# 2798
# 2799
# 2800    Word、Excel、PowerPoint、C/C++、Visual basic、VB Sc...
# 2801
# 2802    Word、Excel、PowerPoint、Outlook、C/C++、Visual bas...
# 2803                              XML、C#.NET、MS SQL、MySQL
# 2804                                AutoCAD、SOLIDWORKS、UG
# 2805                             JAVA、Python、Obj-C、jQuery
# 2806
# 2807
# 2808                                                 JAVA
# 2809
# 2810                                          Android、IOS
# 2811    TCP／IP、C/C++、JAVA、Java Script、HTTP、MS SQL、MySQ...
# 2812    Word、Excel、Outlook、Java Script、ASP.NET、PHP、MS SQL
# 2813
# 2814
# 2815       LINUX、UNIX、Android、JAVA、Java Script、PHP、MS SQL
# 2816                                          LINUX、C/C++
# 2817    Android、C/C++、JAVA、Java Script、PHP、Obj-C、MySQL...
# 2818
# 2819        Java Script、PHP、AJAX、jQuery、MS SQL、MySQL、HTML
# 2820    LINUX、TCP／IP、C/C++、XML、AJAX、HTTP、Python、jQuery...
# 2821                                                C/C++
# 2822
# 2823
# Name: skills, Length: 2824, dtype: object

# %%
df[0:1]
# Out:
#         company                                            content  \
# 0  全國公證檢驗股份有限公司  *應用系統程式開發與維護*應用系統程式測試*應用系統程式文件撰寫*SQL Server 資料...
#
#                                      other_condition post_date  \
# 0  *熟悉 ASP.NET (VB.Net / C#.Net ) 與 SQL Server 資料...  2017/7/7
#
#               skills                     title
# 0  ASP、VB.NET、C#.NET   .NET Programmer 程式開發人員

# %% [markdown]
# ## [Difference between map, applymap and apply methods in Pandas](https://stackoverflow.com/questions/19798153/difference-between-map-applymap-and-apply-methods-in-pandas)
#
#
# Summing up, `apply` works on a row / column basis of a DataFrame, `applymap` works element-wise on a DataFrame, and `map` works element-wise on a Series.

# %%
df['skills'] = df['skills'].apply(str2list)

# %%
df.head(10)
# Out:
#              company                                            content  \
# 0       全國公證檢驗股份有限公司  *應用系統程式開發與維護*應用系統程式測試*應用系統程式文件撰寫*SQL Server 資料...
# 1         全鼎資訊股份有限公司  工作內容 1. 需求訪談 2.整理撰寫系統開發相關文件（如：系統需求與規格書、系統分析與設計...
# 2         耀勝電子股份有限公司  1.協助建立ICarry官網、APP、Kiosk、POS、活動網頁等等，電子商務前後端流程配...
# 3   財團法人資訊工業策進會(資策會)                                 規劃與開發智慧製造服務技術與相關應用
# 4    萬寶華企業管理顧問股份有限公司  -能獨立開發App，有前端Javascript, HTML5開發經驗者優先；-3年以上And...
# 5       特聿科技行銷股份有限公司      1.獨立撰寫網頁、架設網站。 2.針對使用者做介面規劃以及操作優化。 3.跨部門協做專案。
# 6  CHPT_中華精測科技股份有限公司  1. 程式設計與軟體開發 2. 演算法實作 3. 編寫通訊協定函式庫 4. 驅動程式開發 5...
# 7         謦鴻科技股份有限公司                    從事電腦軟體的程式設計、修改、安裝及維護進行軟體之測試與修改。
# 8          英士得科技有限公司  1.從事電腦軟體的程式設計、修改、安裝及維護2.負責控制電路的規格設計、製造與測試3.瑞蕯M...
# 9    魔髮部屋-沃生國際企業有限公司  1.具網頁設計/網站架設及網路規劃經驗二年以上2.熟悉網頁切版製作 將PSD,ai轉換為網頁...
#
#                                      other_condition  post_date  \
# 0  *熟悉 ASP.NET (VB.Net / C#.Net ) 與 SQL Server 資料...   2017/7/7
# 1  擅長工具：Visual Studio .net工作技能：系統架構規劃、系統整合分析、文書處理...  2017/7/11
# 2  1.大型平台開發2年以上經驗.2.善於吸收網路新知.工作技能：資訊設備環境設定、軟體程式設計...  2017/7/17
# 3  1. 具備資訊系統功能技術實作規劃能力2. 具備任一電腦程式語言編寫能力3. 具備英文聽說讀...  2017/7/12
# 4                                                     2017/7/18
# 5  工作技能具軟體程式設計、網路程式設計、資料庫程式設計、網頁軟體操作、網頁語法撰寫。具HTML...  2017/7/17
# 6  1. 大學以上學歷。 2. 擅長C/C++、Python 3. 能理解前項以外的其他程式語言...  2017/7/18
# 7  - 至少3年以上軟體產品開發經驗- 具備HTML、Java Script網頁開發能力- 具T...  2017/7/14
# 8                                 限電子科系畢者，熟組合語言及C語言。  2017/7/16
# 9                                                     2017/7/10
#
#                                               skills  \
# 0                              [ASP, VB.NET, C#.NET]
# 1                          [ASP.NET, MS SQL, ORACLE]
# 2  [JAVA SCRIPT, JQUERY, ILLUSTRATOR, ADOBE PHOTO...
# 3                                                 []
# 4                                                 []
# 5                                                 []
# 6                                                 []
# 7  [WORD, EXCEL, POWERPOINT, ASP, JAVA SCRIPT, VB...
# 8  [WORD, EXCEL, POWERPOINT, OUTLOOK, PROJECT, WI...
# 9                                                 []
#
#                                 title
# 0             .NET Programmer 程式開發人員
# 1                               系統分析師
# 2                               前端工程師
# 3       【106年研發替代役-大數據所】智慧製造系統技術研究工程師
# 4  知名陸商招募在台Android APP工程師(月薪80K~100K)
# 5                               網頁工程師
# 6                             系統開發工程師
# 7                           系統軟體開發工程師
# 8                     單晶片程式設計工程師-高薪面議
# 9                               網頁設計師

# %% [markdown]
# # jsonp

# %%
import re
import json

def loads_jsonp(_jsonp):
    try:
        return json.loads(re.match(".*?({.*}).*",_jsonp,re.S).group(1))
    except:
        raise ValueError('Invalid Input')

# %% [markdown]
# # school
# [file](school)

# %%
# -*- coding: utf-8 -*-
"""
name:
type:
cityID:
address:
lat:
lng:
url:
"""

import re
import os
import csv
import json
import time

import Geocode as gmap
    
regionList = ['[01]新北市', '[31]臺北市', '[32]臺北市', '[33]臺北市', '[34]臺北市', '[35]臺北市',
       '[36]臺北市', '[37]臺北市', '[38]臺北市', '[39]臺北市', '[40]臺北市', '[41]臺北市',
       '[42]臺北市']

path = './school/'
savepath= path + 'data/'
filename = 'school_{}.json'

for file in os.listdir(path):
    filepath = path + filelist[0]
    with open(filepath, encoding='utf8') as rf:
        data = csv.DictReader(rf)
        for row in data:
            if row.get('縣市名稱') in regionList:
                temp = {}
                #name
                temp['name'] = row.get('學校名稱')
                #cityID & address
                address = row.get('地址')
                temp['cityID'] = re.findall('\[(\d{3})\]',address)[0]
                temp['address'] = address.split(']')[-1]
                #lat lng
                temp.update(gmap.geocoding(address))
                #type
                temp['type'] = 'school'
                #url
                temp['url'] = row.get('網址')

                print(row.get('代碼'))
                #save
                with open(savepath + filename.format(row.get('代碼')),
                         'w', encoding='utf8') as wf:
                    json.dump(temp, wf)
                time.sleep(0.1)
# Out:
# OrderedDict([('代碼', '011601'), ('學校名稱', '私立育才國小'), ('公/私立', '私立'), ('縣市名稱', '[01]新北市'), ('地址', '[234]新北市永和區福和路125巷20號'), ('電話', '(02)29214630'), ('網址', 'http://www.ytes.ntpc.edu.tw')])
# OrderedDict([('代碼', '011602'), ('學校名稱', '私立聖心國小'), ('公/私立', '私立'), ('縣市名稱', '[01]新北市'), ('地址', '[249]新北市八里區龍米路一段261號'), ('電話', '(02)26182330'), ('網址', 'http://lshes.com/school/')])
# OrderedDict([('代碼', '011603'), ('學校名稱', '私立及人國小'), ('公/私立', '私立'), ('縣市名稱', '[01]新北市'), ('地址', '[234]新北市永和區文化路172號'), ('電話', '(02)29212145'), ('網址', 'http://www.cjps.ntpc.edu.tw')])
# OrderedDict([('代碼', '011604'), ('學校名稱', '私立竹林國小'), ('公/私立', '私立'), ('縣市名稱', '[01]新北市'), ('地址', '[234]新北市永和區竹林路34號'), ('電話', '(02)29243919'), ('網址', 'http://www.clse.ntpc.edu.tw')])
# OrderedDict([('代碼', '011606'), ('學校名稱', '私立信賢種籽親子實小'), ('公/私立', '私立'), ('縣市名稱', '[01]新北市'), ('地址', '[233]新北市烏來區信賢里娃娃谷41號'), ('電話', '(02)26616648#266'), ('網址', 'http://www.seedling.tw')])
# OrderedDict([('代碼', '013601'), ('學校名稱', '市立北大國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[237]新北市三峽區國光街100號'), ('電話', '(02)86716836'), ('網址', 'http://www.bdes.ntpc.edu.tw/')])
# OrderedDict([('代碼', '014601'), ('學校名稱', '市立板橋國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[220]新北市板橋區黃石里文化路一段23號'), ('電話', '(02)29686834'), ('網址', 'http://www.pcps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014602'), ('學校名稱', '市立國光國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[220]新北市板橋區中正路325巷30號'), ('電話', '(02)29680611'), ('網址', 'http://www.kkes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014603'), ('學校名稱', '市立新埔國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[220]新北市板橋區新翠里陽明街206號'), ('電話', '(02)22571830'), ('網址', 'http://www.spes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014604'), ('學校名稱', '市立埔墘國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[220]新北市板橋區永豐街42之8號'), ('電話', '(02)29616690'), ('網址', 'http://www.pces.ntpc.edu.tw')])
# OrderedDict([('代碼', '014605'), ('學校名稱', '市立莒光國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[220]新北市板橋區華翠里莒光路163號'), ('電話', '(02)22517272'), ('網址', 'http://www.jges.ntpc.edu.tw')])
# OrderedDict([('代碼', '014606'), ('學校名稱', '市立後埔國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[220]新北市板橋區重慶路157號'), ('電話', '(02)29614142'), ('網址', 'http://www.hpes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014607'), ('學校名稱', '市立海山國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[220]新北市板橋區漢生東路280號'), ('電話', '(02)29545725'), ('網址', 'http://www.hsps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014608'), ('學校名稱', '市立江翠國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[220]新北市板橋區松翠里文化路二段413號'), ('電話', '(02)22526880'), ('網址', 'http://www.ctes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014610'), ('學校名稱', '市立文聖國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[220]新北市板橋區文聖街86號'), ('電話', '(02)22530782'), ('網址', 'http://www.wses.ntpc.edu.tw')])
# OrderedDict([('代碼', '014611'), ('學校名稱', '市立沙崙國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[220]新北市板橋區篤行路二段132號'), ('電話', '(02)26812764'), ('網址', 'http://www.sles.ntpc.edu.tw')])
# OrderedDict([('代碼', '014612'), ('學校名稱', '市立文德國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[220]新北市板橋區新翠里英士路179號'), ('電話', '(02)22577193'), ('網址', 'http://www.wdps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014613'), ('學校名稱', '市立樹林國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[238]新北市樹林區樹西里育英街176號'), ('電話', '(02)26812014'), ('網址', 'http://www.slps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014614'), ('學校名稱', '市立文林國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[238]新北市樹林區潭底里千歲街59號'), ('電話', '(02)26812625'), ('網址', 'http://www.twles.ntpc.edu.tw')])
# OrderedDict([('代碼', '014615'), ('學校名稱', '市立大同國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[238]新北市樹林區大同里大同街43號'), ('電話', '(02)86865486'), ('網址', 'http://www.ttps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014616'), ('學校名稱', '市立武林國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[238]新北市樹林區保安街二段151號'), ('電話', '(02)26812475'), ('網址', 'http://www.wles.ntpc.edu.tw')])
# OrderedDict([('代碼', '014617'), ('學校名稱', '市立山佳國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[238]新北市樹林區中山路三段5號'), ('電話', '(02)26806673'), ('網址', 'http://www.sjes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014618'), ('學校名稱', '市立育德國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[238]新北市樹林區中山里佳園路一段34號'), ('電話', '(02)26805557'), ('網址', 'http://www.ytps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014619'), ('學校名稱', '市立柑園國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[238]新北市樹林區柑園街一段353號'), ('電話', '(02)26802507'), ('網址', 'http://www.gyes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014620'), ('學校名稱', '市立鶯歌國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[239]新北市鶯歌區同慶里尖山埔路106號'), ('電話', '(02)26792038'), ('網址', 'http://www.ykes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014621'), ('學校名稱', '市立二橋國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[239]新北市鶯歌區二橋里中正三路106號'), ('電話', '(02)26792364'), ('網址', 'http://www.eqes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014622'), ('學校名稱', '市立中湖國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[239]新北市鶯歌區中湖里中湖街25號'), ('電話', '(02)86775640'), ('網址', 'http://www.chues.ntpc.edu.tw')])
# OrderedDict([('代碼', '014623'), ('學校名稱', '市立鳳鳴國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[239]新北市鶯歌區鳳鳴里永和街120號'), ('電話', '(02)26797554'), ('網址', 'http://www.fmes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014624'), ('學校名稱', '市立三峽國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[237]新北市三峽區中山路16號'), ('電話', '(02)26711018'), ('網址', 'http://www.shps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014625'), ('學校名稱', '市立大埔國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[237]新北市三峽區大埔路130號'), ('電話', '(02)26712523'), ('網址', 'http://www.tpps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014626'), ('學校名稱', '市立民義國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[237]新北市三峽區嘉添里白雞路40號'), ('電話', '(02)26711895'), ('網址', 'http://www.myes.ntpc.edu.tw/default.asp')])
# OrderedDict([('代碼', '014627'), ('學校名稱', '市立成福國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[237]新北市三峽區溪東里溪東路213號'), ('電話', '(02)86764945'), ('網址', 'http://www.chenfu.ntpc.edu.tw')])
# OrderedDict([('代碼', '014628'), ('學校名稱', '市立大成國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[237]新北市三峽區成福路251巷二號'), ('電話', '(02)26726521'), ('網址', 'http://www.dces.ntpc.edu.tw')])
# OrderedDict([('代碼', '014629'), ('學校名稱', '市立建安國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[237]新北市三峽區安坑里建安路67號'), ('電話', '(02)26726783'), ('網址', 'http://www.caes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014630'), ('學校名稱', '市立插角國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[237]新北市三峽區插角里插角路39號'), ('電話', '(02)26720230'), ('網址', 'http://www.cgps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014631'), ('學校名稱', '市立有木國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[237]新北市三峽區有木里131號'), ('電話', '(02)26720067'), ('網址', 'http://www.ymps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014632'), ('學校名稱', '市立五寮國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[237]新北市三峽區五寮里69號'), ('電話', '(02)26720298'), ('網址', 'http://www.wres.ntpc.edu.tw')])
# OrderedDict([('代碼', '014633'), ('學校名稱', '市立中和國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[235]新北市中和區中和路100號'), ('電話', '(02)22492550'), ('網址', 'http://www.jhes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014634'), ('學校名稱', '市立復興國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[235]新北市中和區復興路301巷6號'), ('電話', '(02)22472993'), ('網址', 'http://www.fsps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014635'), ('學校名稱', '市立興南國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[235]新北市中和區興南路一段135巷24號'), ('電話', '(02)29422349'), ('網址', 'http://www.hnps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014636'), ('學校名稱', '市立秀山國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[235]新北市中和區立人街2號'), ('電話', '(02)29434353'), ('網址', 'http://www.ssps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014637'), ('學校名稱', '市立積穗國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[235]新北市中和區員山路154號'), ('電話', '(02)22225533'), ('網址', 'http://www.tjsps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014638'), ('學校名稱', '市立自強國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[235]新北市中和區莒光路200號'), ('電話', '(02)29557936'), ('網址', 'http://www.jcps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014639'), ('學校名稱', '市立錦和國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[235]新北市中和區圓通路292號'), ('電話', '(02)22479495'), ('網址', 'http://www.chps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014640'), ('學校名稱', '市立景新國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[235]新北市中和區景新街467巷37號'), ('電話', '(02)29448021'), ('網址', 'http://www.jsps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014641'), ('學校名稱', '市立永和國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[234]新北市永和區秀朗路一段120號'), ('電話', '(02)29214615'), ('網址', 'http://www.yhes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014642'), ('學校名稱', '市立秀朗國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[234]新北市永和區得和路202號'), ('電話', '(02)29420451'), ('網址', 'http://www.hles.ntpc.edu.tw')])
# OrderedDict([('代碼', '014643'), ('學校名稱', '市立頂溪國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[234]新北市永和區文化路133號'), ('電話', '(02)29212058'), ('網址', 'http://web2.thps.ntpc.edu.tw/')])
# OrderedDict([('代碼', '014644'), ('學校名稱', '市立網溪國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[234]新北市永和區竹林路79號'), ('電話', '(02)89264470'), ('網址', 'http://www.whps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014645'), ('學校名稱', '市立永平國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[234]新北市永和區保生路25號'), ('電話', '(02)29259879'), ('網址', 'http://www.ypes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014646'), ('學校名稱', '市立土城國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[236]新北市土城區興城路17號'), ('電話', '(02)22700177'), ('網址', 'http://www.ttcps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014647'), ('學校名稱', '市立清水國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[236]新北市土城區金城路二段356號'), ('電話', '(02)22618316'), ('網址', 'http://www.cses.ntpc.edu.tw')])
# OrderedDict([('代碼', '014648'), ('學校名稱', '市立頂埔國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[236]新北市土城區頂福里中央路四段205號'), ('電話', '(02)22686800'), ('網址', 'http://www.dpes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014649'), ('學校名稱', '市立廣福國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[236]新北市土城區學府路一段127號'), ('電話', '(02)22626782'), ('網址', 'http://www.gfes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014650'), ('學校名稱', '市立汐止國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[221]新北市汐止區大同路二段313號'), ('電話', '(02)26477271'), ('網址', 'http://www.hjes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014651'), ('學校名稱', '市立長安國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[221]新北市汐止區長興街一段80號'), ('電話', '(02)86480944'), ('網址', 'http://www.chanes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014652'), ('學校名稱', '市立保長國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[221]新北市汐止區大同路三段553號'), ('電話', '(02)86482502'), ('網址', 'http://www.bjes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014653'), ('學校名稱', '市立崇德國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[221]新北市汐止區茄苳里茄苳路158號'), ('電話', '(02)86482052'), ('網址', 'http://www.cdps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014654'), ('學校名稱', '市立北港國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[221]新北市汐止區汐萬路二段279號'), ('電話', '(02)26462832'), ('網址', 'http://www.bkes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014655'), ('學校名稱', '市立北峰國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[221]新北市汐止區中興里環河街1號'), ('電話', '(02)26941817'), ('網址', 'http://www.pfes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014656'), ('學校名稱', '市立東山國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[221]新北市汐止區東山里汐平路二段76號'), ('電話', '(02)26416170'), ('網址', 'http://www.dsps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014657'), ('學校名稱', '市立白雲國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[221]新北市汐止區福山里民權街二段90號'), ('電話', '(02)26403909'), ('網址', 'http://www.pyps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014658'), ('學校名稱', '市立萬里國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[207]新北市萬里區瑪鋉路18號'), ('電話', '(02)24922034'), ('網址', 'http://www.wlps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014659'), ('學校名稱', '市立野柳國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[207]新北市萬里區野柳里港東路167號'), ('電話', '(02)24922512'), ('網址', 'http://www.ylps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014660'), ('學校名稱', '市立大鵬國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[207]新北市萬里區大鵬里加投路14號'), ('電話', '(02)24988131'), ('網址', 'http://www.tpes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014661'), ('學校名稱', '市立大坪國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[207]新北市萬里區雙興里大坪路1號'), ('電話', '(02)24929461'), ('網址', 'http://www.dpps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014662'), ('學校名稱', '市立崁腳國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[207]新北市萬里區崁脚里崁脚路59號'), ('電話', '(02)24922037'), ('網址', 'http://www.kjps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014663'), ('學校名稱', '市立金山國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[208]新北市金山區中山路234號'), ('電話', '(02)24981125'), ('網址', 'http://www.tpcses.ntpc.edu.tw')])
# OrderedDict([('代碼', '014664'), ('學校名稱', '市立中角國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[208]新北市金山區萬壽里海興路49號'), ('電話', '(02)24982413'), ('網址', 'http://www.jjps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014665'), ('學校名稱', '市立三和國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[208]新北市金山區重和里十一鄰六股林口38號'), ('電話', '(02)24080417'), ('網址', 'http://www.sanho.ntpc.edu.tw')])
# OrderedDict([('代碼', '014666'), ('學校名稱', '市立新店國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[231]新北市新店區新店路2號'), ('電話', '(02)29103483'), ('網址', 'http://www.shdes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014667'), ('學校名稱', '市立直潭國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[231]新北市新店區直潭路92號'), ('電話', '(02)26667278'), ('網址', 'http://www.jtes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014668'), ('學校名稱', '市立青潭國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[231]新北市新店區北宜路二段80號'), ('電話', '(02)22173146'), ('網址', 'http://www.chtes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014669'), ('學校名稱', '市立雙峰國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[231]新北市新店區北宜路三段66號'), ('電話', '(02)22174543'), ('網址', 'http://www.sfes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014670'), ('學校名稱', '市立大豐國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[231]新北市新店區民族路108號'), ('電話', '(02)22192619'), ('網址', 'http://www.dfes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014671'), ('學校名稱', '市立中正國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[231]新北市新店區三民路36號'), ('電話', '(02)29125432'), ('網址', 'http://www.ccps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014672'), ('學校名稱', '市立安坑國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[231]新北市新店區安忠路36號'), ('電話', '(02)22110560'), ('網址', 'http://www.takes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014673'), ('學校名稱', '市立雙城國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[231]新北市新店區安康路三段322號'), ('電話', '(02)22156511'), ('網址', 'http://www.tcsps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014674'), ('學校名稱', '市立屈尺國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[231]新北市新店區屈尺路55號'), ('電話', '(02)26667490'), ('網址', 'http://www.ccyes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014675'), ('學校名稱', '市立龜山國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[231]新北市新店區新烏路三段99巷10號'), ('電話', '(02)26667317'), ('網址', 'http://www.gses.ntpc.edu.tw')])
# OrderedDict([('代碼', '014676'), ('學校名稱', '市立深坑國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[222]新北市深坑區深坑里文化街45號'), ('電話', '(02)26624675'), ('網址', 'http://www.tskes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014677'), ('學校名稱', '市立石碇國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[223]新北市石碇區石碇里石碇西街15號'), ('電話', '(02)26631244'), ('網址', 'http://www.stes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014678'), ('學校名稱', '市立和平國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[223]新北市石碇區隆盛里八分寮5號'), ('電話', '(02)26631405'), ('網址', 'http://www.hpps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014679'), ('學校名稱', '市立永定國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[223]新北市石碇區永定里靜安路一段245號'), ('電話', '(02)26631288'), ('網址', 'http://www.tydes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014680'), ('學校名稱', '市立雲海國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[223]新北市石碇區北宜路五段坑內巷1號'), ('電話', '(02)26651715'), ('網址', 'http://www.whies.ntpc.edu.tw')])
# OrderedDict([('代碼', '014682'), ('學校名稱', '市立坪林國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[232]新北市坪林區坪林里坪林街114號'), ('電話', '(02)26656213'), ('網址', 'http://www.plnes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014684'), ('學校名稱', '市立烏來國(中)小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[233]新北市烏來區啦卡路5號'), ('電話', '(02)26616482'), ('網址', 'http://www.wups.ntpc.edu.tw')])
# OrderedDict([('代碼', '014685'), ('學校名稱', '市立福山國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[233]新北市烏來區福山里李茂岸56號'), ('電話', '(02)26616124'), ('網址', 'http://www.fses.ntpc.edu.tw')])
# OrderedDict([('代碼', '014686'), ('學校名稱', '市立瑞芳國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[224]新北市瑞芳區龍川里中山路2號'), ('電話', '(02)24972058'), ('網址', 'http://www.rfes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014687'), ('學校名稱', '市立義方國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[224]新北市瑞芳區龍山里逢甲路360號'), ('電話', '(02)24970961'), ('網址', 'http://www.jfps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014688'), ('學校名稱', '市立瑞柑國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[224]新北市瑞芳區明燈路一段18巷13號'), ('電話', '(02)24971009'), ('網址', 'http://www.rges.ntpc.edu.tw')])
# OrderedDict([('代碼', '014689'), ('學校名稱', '市立瑞濱國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[224]新北市瑞芳區瑞濱路34號'), ('電話', '(02)24978184'), ('網址', 'http://www.jpes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014690'), ('學校名稱', '市立九份國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[224]新北市瑞芳區永慶里崙頂路145號'), ('電話', '(02)24972263'), ('網址', 'http://www.jfes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014691'), ('學校名稱', '市立瓜山國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[224]新北市瑞芳區石山里五號路306號'), ('電話', '(02)24962036'), ('網址', 'http://www.gsps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014692'), ('學校名稱', '市立濂洞國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[224]新北市瑞芳區濓洞里洞頂路101巷80號'), ('電話', '(02)24961330'), ('網址', 'http://163.20.89.1')])
# OrderedDict([('代碼', '014693'), ('學校名稱', '市立猴硐國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[224]新北市瑞芳區弓橋里九芎橋路69-1號'), ('電話', '(02)24960450'), ('網址', 'http://www.htes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014694'), ('學校名稱', '市立瑞亭國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[224]新北市瑞芳區四腳亭埔路23號'), ('電話', '(02)24971726'), ('網址', 'http://www.rtes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014695'), ('學校名稱', '市立吉慶國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[224]新北市瑞芳區吉安里大埔路95號'), ('電話', '(02)24576405'), ('網址', 'http://cces.ntpc.edu.tw')])
# OrderedDict([('代碼', '014696'), ('學校名稱', '市立鼻頭國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[224]新北市瑞芳區鼻頭里鼻頭路99號'), ('電話', '(02)24911571'), ('網址', 'http://www.pitoues.ntpc.edu.tw')])
# OrderedDict([('代碼', '014697'), ('學校名稱', '市立雙溪國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[227]新北市雙溪區共和里東榮街54號'), ('電話', '(02)24931005'), ('網址', 'http://www.sses.ntpc.edu.tw')])
# OrderedDict([('代碼', '014698'), ('學校名稱', '市立柑林國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[227]新北市雙溪區長源里柑腳3號'), ('電話', '(02)24931624'), ('網址', 'http://www.gles.ntpc.edu.tw')])
# OrderedDict([('代碼', '014699'), ('學校名稱', '市立上林國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[227]新北市雙溪區上林里內平林60號'), ('電話', '(02)24931671'), ('網址', 'http://www.ulps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014700'), ('學校名稱', '市立牡丹國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[227]新北市雙溪區三貂里政光路3號'), ('電話', '(02)24931240'), ('網址', 'http://www.mdps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014702'), ('學校名稱', '市立貢寮國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[228]新北市貢寮區雙玉里學苑街7號'), ('電話', '(02)24941274'), ('網址', 'http://www.kles.ntpc.edu.tw')])
# OrderedDict([('代碼', '014703'), ('學校名稱', '市立福隆國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[228]新北市貢寮區福隆里東興街35號'), ('電話', '(02)24991449'), ('網址', 'http://www.flps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014704'), ('學校名稱', '市立澳底國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[228]新北市貢寮區真理里延平街10號'), ('電話', '(02)24901432'), ('網址', 'http://www.auti.ntpc.edu.tw')])
# OrderedDict([('代碼', '014706'), ('學校名稱', '市立和美國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[228]新北市貢寮區和美里龍洞街1之9號'), ('電話', '(02)24909431'), ('網址', 'http://www.hmps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014708'), ('學校名稱', '市立福連國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[228]新北市貢寮區福連里福連街1號'), ('電話', '(02)24991194'), ('網址', 'http://www.fulps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014709'), ('學校名稱', '市立平溪國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[226]新北市平溪區平溪街56號'), ('電話', '(02)24951038'), ('網址', 'http://www.pses.ntpc.edu.tw')])
# OrderedDict([('代碼', '014710'), ('學校名稱', '市立菁桐國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[226]新北市平溪區菁桐街45號'), ('電話', '(02)24951009'), ('網址', 'http://www.tgtes.ntpc.edu.tw/')])
# OrderedDict([('代碼', '014711'), ('學校名稱', '市立十分國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[226]新北市平溪區十分里十分街157號'), ('電話', '(02)24958305'), ('網址', 'http://www.tsfes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014712'), ('學校名稱', '市立淡水國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[251]新北市淡水區協元里中山路160號'), ('電話', '(02)26212755'), ('網址', 'http://www.tsps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014713'), ('學校名稱', '市立育英國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[251]新北市淡水區埤島里14號'), ('電話', '(02)26214390'), ('網址', 'http://www.yies.ntpc.edu.tw')])
# OrderedDict([('代碼', '014714'), ('學校名稱', '市立文化國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[251]新北市淡水區文化里真理街6號'), ('電話', '(02)26212031'), ('網址', 'http://www.twhps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014715'), ('學校名稱', '市立天生國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[251]新北市淡水區淡海路72巷26號'), ('電話', '(02)28052695'), ('網址', 'http://www.tisnes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014716'), ('學校名稱', '市立水源國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[251]新北市淡水區水源里北新路二段15號'), ('電話', '(02)26211347'), ('網址', 'http://www.hyes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014717'), ('學校名稱', '市立興仁國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[251]新北市淡水區興仁路101巷10號'), ('電話', '(02)26213783'), ('網址', 'http://www.shrens.ntpc.edu.tw')])
# OrderedDict([('代碼', '014718'), ('學校名稱', '市立忠山國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[251]新北市淡水區忠山里行忠路899號'), ('電話', '(02)26216139'), ('網址', 'http://www.tcses.ntpc.edu.tw')])
# OrderedDict([('代碼', '014719'), ('學校名稱', '市立屯山國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[251]新北市淡水區淡金路五段111號'), ('電話', '(02)28012591'), ('網址', 'http://www.ttses.ntpc.edu.tw')])
# OrderedDict([('代碼', '014720'), ('學校名稱', '市立中泰國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[251]新北市淡水區中和里北勢子5號'), ('電話', '(02)28012033'), ('網址', 'http://www.ctps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014721'), ('學校名稱', '市立坪頂國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[251]新北市淡水區坪頂路757號'), ('電話', '(02)86263105'), ('網址', 'http://www.pdes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014722'), ('學校名稱', '市立竹圍國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[251]新北市淡水區中正東路二段145號'), ('電話', '(02)28091475'), ('網址', 'http://www.cwps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014723'), ('學校名稱', '市立石門國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[253]新北市石門區尖鹿里中央路9號'), ('電話', '(02)26381263'), ('網址', 'http://www.smes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014724'), ('學校名稱', '市立乾華國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[253]新北市石門區茂林里茂林社區74號'), ('電話', '(02)26381269'), ('網址', 'http://www.cwes.ntpc.edu.tw/')])
# OrderedDict([('代碼', '014725'), ('學校名稱', '市立老梅國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[253]新北市石門區老梅里老梅路10號'), ('電話', '(02)26381258'), ('網址', 'http://www.lmes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014726'), ('學校名稱', '市立三芝國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[252]新北市三芝區埔頭里育英街22號'), ('電話', '(02)26362005'), ('網址', 'http://www.sces.ntpc.edu.tw')])
# OrderedDict([('代碼', '014727'), ('學校名稱', '市立橫山國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[252]新北市三芝區橫山里86號'), ('電話', '(02)26362473'), ('網址', 'http://www.hses.ntpc.edu.tw')])
# OrderedDict([('代碼', '014728'), ('學校名稱', '市立興華國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[252]新北市三芝區興華里5號'), ('電話', '(02)26371366'), ('網址', 'http://www.hhes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014729'), ('學校名稱', '市立新莊國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[242]新北市新莊區立人里中正路86號'), ('電話', '(02)29931201'), ('網址', 'http://www.scps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014730'), ('學校名稱', '市立中港國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[242]新北市新莊區立志里中港一街142號'), ('電話', '(02)29925550'), ('網址', 'http://www.jgps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014731'), ('學校名稱', '市立思賢國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[242]新北市新莊區自立街229號'), ('電話', '(02)29980443'), ('網址', 'http://www.sies.ntpc.edu.tw')])
# OrderedDict([('代碼', '014732'), ('學校名稱', '市立頭前國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[242]新北市新莊區頭前里化成路231號'), ('電話', '(02)29920238'), ('網址', 'http://www.tcps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014733'), ('學校名稱', '市立國泰國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[242]新北市新莊區中正路386號'), ('電話', '(02)29043693'), ('網址', 'http://www.gtps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014734'), ('學校名稱', '市立豐年國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[242]新北市新莊區國泰里瓊泰路116號'), ('電話', '(02)22017102'), ('網址', 'http://www.fnes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014735'), ('學校名稱', '市立丹鳳國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[242]新北市新莊區新北大道七段437號'), ('電話', '(02)29035355'), ('網址', 'http://163.20.170.180/')])
# OrderedDict([('代碼', '014736'), ('學校名稱', '市立光華國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[242]新北市新莊區龍安路452號'), ('電話', '(02)22058866'), ('網址', 'http://www.ghes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014737'), ('學校名稱', '市立民安國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[242]新北市新莊區民全里民安路二六一號'), ('電話', '(02)22056777'), ('網址', 'http://www.maes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014738'), ('學校名稱', '市立昌隆國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[242]新北市新莊區昌隆街63號'), ('電話', '(02)29962351'), ('網址', 'http://www.clps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014739'), ('學校名稱', '市立泰山國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[243]新北市泰山區泰林路二段255號'), ('電話', '(02)29098842'), ('網址', 'http://www.tses.ntpc.edu.tw')])
# OrderedDict([('代碼', '014740'), ('學校名稱', '市立明志國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[243]新北市泰山區新生路2號'), ('電話', '(02)29061133'), ('網址', 'http://www.mjes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014741'), ('學校名稱', '市立成州國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[248]新北市五股區成泰路三段493號'), ('電話', '(02)22933613'), ('網址', 'http://www.cjoes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014742'), ('學校名稱', '市立更寮國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[248]新北市五股區四維路2號'), ('電話', '(02)29824591'), ('網址', 'http://www.glps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014743'), ('學校名稱', '市立五股國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[248]新北市五股區五股里成泰路二段49號'), ('電話', '(02)22917191'), ('網址', 'http://www.wkes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014744'), ('學校名稱', '市立蘆洲國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[247]新北市蘆洲區中正路100號'), ('電話', '(02)22816202'), ('網址', 'http://www.lces.ntpc.edu.tw')])
# OrderedDict([('代碼', '014745'), ('學校名稱', '市立鷺江國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[247]新北市蘆洲區民族路7號'), ('電話', '(02)22819980'), ('網址', 'http://www.lcps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014746'), ('學校名稱', '市立八里國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[249]新北市八里區舊城里中山路二段338號'), ('電話', '(02)26102217'), ('網址', 'http://www.ples.ntpc.edu.tw')])
# OrderedDict([('代碼', '014747'), ('學校名稱', '市立長坑國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[249]新北市八里區中華路三段236號'), ('電話', '(02)26102037'), ('網址', 'http://www.ckes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014748'), ('學校名稱', '市立米倉國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[249]新北市八里區米倉里龍米路2段129巷1號'), ('電話', '(02)26182202'), ('網址', 'http://www.mtes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014749'), ('學校名稱', '市立林口國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[244]新北市林口區菁湖里林口路76號'), ('電話', '(02)26011010'), ('網址', 'http://www.lkes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014750'), ('學校名稱', '市立南勢國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[244]新北市林口區南勢五街2號'), ('電話', '(02)26091020'), ('網址', 'http://www.nses.ntpc.edu.tw')])
# OrderedDict([('代碼', '014751'), ('學校名稱', '市立嘉寶國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[244]新北市林口區嘉寶里22號'), ('電話', '(02)26052716'), ('網址', 'http://www.jbes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014752'), ('學校名稱', '市立瑞平國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[244]新北市林口區太平里後坑路34之1號'), ('電話', '(02)26052779'), ('網址', 'http://www.rpes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014753'), ('學校名稱', '市立興福國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[244]新北市林口區下福里20鄰一○之一號'), ('電話', '(02)26062895'), ('網址', 'http://www.hfps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014754'), ('學校名稱', '市立三重國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[241]新北市三重區三和路三段1號'), ('電話', '(02)29722095'), ('網址', 'http://www.tsces.ntpc.edu.tw')])
# OrderedDict([('代碼', '014755'), ('學校名稱', '市立永福國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[241]新北市三重區永福里永福街66號'), ('電話', '(02)22876716'), ('網址', 'http://www.yfps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014756'), ('學校名稱', '市立光榮國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[241]新北市三重區介壽路32號'), ('電話', '(02)29730392'), ('網址', 'http://www.kjpps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014757'), ('學校名稱', '市立厚德國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[241]新北市三重區忠孝路一段70號'), ('電話', '(02)29868825'), ('網址', 'http://www.hdes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014758'), ('學校名稱', '市立碧華國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[241]新北市三重區五華街160號'), ('電話', '(02)28577792'), ('網址', 'http://www.bhes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014759'), ('學校名稱', '市立三光國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[241]新北市三重區同安里大同南路157號'), ('電話', '(02)29753308'), ('網址', 'http://www.skes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014760'), ('學校名稱', '市立光興國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[241]新北市三重區正義南路62號'), ('電話', '(02)29755352'), ('網址', 'http://www.kses.ntpc.edu.tw')])
# OrderedDict([('代碼', '014761'), ('學校名稱', '市立正義國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[241]新北市三重區信義西街31號'), ('電話', '(02)29853138'), ('網址', 'http://www.jyes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014762'), ('學校名稱', '市立修德國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[241]新北市三重區重陽路三段3號'), ('電話', '(02)29800495'), ('網址', 'http://www.sude.ntpc.edu.tw')])
# OrderedDict([('代碼', '014763'), ('學校名稱', '市立二重國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[241]新北市三重區二重里大有街10號'), ('電話', '(02)29846446'), ('網址', 'http://www.eces.ntpc.edu.tw')])
# OrderedDict([('代碼', '014764'), ('學校名稱', '市立興穀國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[241]新北市三重區五谷王北街46號'), ('電話', '(02)29990725'), ('網址', 'http://www.skps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014765'), ('學校名稱', '市立興化國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[248]新北市新莊區福興里五工二路50巷2號'), ('電話', '(02)22991001'), ('網址', 'http://www.tshes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014766'), ('學校名稱', '市立中山國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[220]新北市板橋區大觀路二段59巷31號'), ('電話', '(02)22755313'), ('網址', 'http://www.jshps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014767'), ('學校名稱', '市立三多國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[238]新北市樹林區三福街52號'), ('電話', '(02)26880698'), ('網址', 'http://www.sdes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014768'), ('學校名稱', '市立實踐國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[220]新北市板橋區實踐路93巷51號'), ('電話', '(02)29531233'), ('網址', 'http://www.sjps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014769'), ('學校名稱', '市立大觀國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[220]新北市板橋區大觀路一段30號'), ('電話', '(02)29603373'), ('網址', 'http://www.tgps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014770'), ('學校名稱', '市立溪洲國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[220]新北市板橋區金門街289號'), ('電話', '(02)26867705'), ('網址', 'http://www.sips.ntpc.edu.tw')])
# OrderedDict([('代碼', '014771'), ('學校名稱', '市立信義國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[220]新北市板橋區四川路二段245巷60號'), ('電話', '(02)89667817'), ('網址', 'http://www.thyes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014772'), ('學校名稱', '市立重慶國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[220]新北市板橋區廣和街31號'), ('電話', '(02)29565592'), ('網址', 'http://www.cges.ntpc.edu.tw')])
# OrderedDict([('代碼', '014773'), ('學校名稱', '市立樂利國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[236]新北市土城區裕生路65號'), ('電話', '(02)22662568'), ('網址', 'http://www.llps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014774'), ('學校名稱', '市立安和國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[236]新北市土城區延和路23號'), ('電話', '(02)22603451'), ('網址', 'http://www.anhoes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014775'), ('學校名稱', '市立彭福國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[238]新北市樹林區忠孝街30號'), ('電話', '(02)86866589'), ('網址', 'http://www.pfps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014776'), ('學校名稱', '市立育林國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[238]新北市樹林區復興路395號'), ('電話', '(02)26832112'), ('網址', 'http://www.yles.ntpc.edu.tw')])
# OrderedDict([('代碼', '014777'), ('學校名稱', '市立建國國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[239]新北市鶯歌區育英街2號'), ('電話', '(02)26709228'), ('網址', 'http://www.ckps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014778'), ('學校名稱', '市立安溪國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[237]新北市三峽區中華路42號'), ('電話', '(02)26731488'), ('網址', 'http://www.ases.ntpc.edu.tw')])
# OrderedDict([('代碼', '014779'), ('學校名稱', '市立樟樹國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[221]新北市汐止區樟樹一路141巷2號'), ('電話', '(02)26421407'), ('網址', 'http://www.tctes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014780'), ('學校名稱', '市立金美國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[208]新北市金山區忠孝一路111號'), ('電話', '(02)24986503'), ('網址', 'http://www.gmes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014781'), ('學校名稱', '市立新和國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[231]新北市新店區安和路三段100號'), ('電話', '(02)29400170'), ('網址', 'http://www.hhps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014782'), ('學校名稱', '市立鄧公國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[251]新北市淡水區學府里學府路99號'), ('電話', '(02)26297121'), ('網址', 'http://www.dkes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014783'), ('學校名稱', '市立新興國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[251]新北市淡水區新興街123號'), ('電話', '(02)26203645'), ('網址', 'http://www.shes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014784'), ('學校名稱', '市立重陽國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[241]新北市三重區中正北路113號'), ('電話', '(02)29826272'), ('網址', 'http://www.cyps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014785'), ('學校名稱', '市立五華國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[241]新北市三重區集賢路89號'), ('電話', '(02)28578087'), ('網址', 'http://www.whes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014786'), ('學校名稱', '市立成功國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[247]新北市蘆洲區長安街311號'), ('電話', '(02)22858998'), ('網址', 'http://www.tces.ntpc.edu.tw')])
# OrderedDict([('代碼', '014787'), ('學校名稱', '市立仁愛國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[247]新北市蘆洲區民族路488號'), ('電話', '(02)22838815'), ('網址', 'http://www.jaes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014788'), ('學校名稱', '市立榮富國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[242]新北市新莊區中和街193號'), ('電話', '(02)22769020'), ('網址', 'http://www.lfes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014789'), ('學校名稱', '市立裕民國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[242]新北市新莊區裕民街123號'), ('電話', '(02)29062407'), ('網址', 'http://www.ymes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014790'), ('學校名稱', '市立新泰國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[242]新北市新莊區公園一路91號'), ('電話', '(02)29971005'), ('網址', 'http://www.stps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014791'), ('學校名稱', '市立中信國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[242]新北市新莊區中信街168號'), ('電話', '(02)85211131'), ('網址', 'http://www.ches.ntpc.edu.tw')])
# OrderedDict([('代碼', '014792'), ('學校名稱', '市立德音國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[248]新北市五股區明德路2號'), ('電話', '(02)22924152'), ('網址', 'http://www.tyes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014793'), ('學校名稱', '市立麗園國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[244]新北市林口區忠孝路591號'), ('電話', '(02)26091061'), ('網址', 'http://www.lyaes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014794'), ('學校名稱', '市立北新國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[231]新北市新店區寶橋路8號'), ('電話', '(02)29189300'), ('網址', 'http://www.tspes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014795'), ('學校名稱', '市立同榮國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[243]新北市泰山區公園路33號'), ('電話', '(02)22968551'), ('網址', 'http://www.tres.ntpc.edu.tw')])
# OrderedDict([('代碼', '014796'), ('學校名稱', '市立光復國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[235]新北市中和區光環路二段1號'), ('電話', '(02)32348654'), ('網址', 'http://www.kfes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014797'), ('學校名稱', '市立秀峰國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[221]新北市汐止區仁愛路90號'), ('電話', '(02)26480611'), ('網址', 'http://www.sfps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014798'), ('學校名稱', '市立金龍國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[221]新北市汐止區明峰街201號'), ('電話', '(02)26959941'), ('網址', 'http://www.gdps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014799'), ('學校名稱', '市立介壽國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[237]新北市三峽區大同路1號'), ('電話', '(02)26712392'), ('網址', 'http://www.jses.ntpc.edu.tw')])
# OrderedDict([('代碼', '014801'), ('學校名稱', '市立昌平國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[242]新北市新莊區昌平街200號'), ('電話', '(02)85215492'), ('網址', 'http://www.cpps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014802'), ('學校名稱', '市立麗林國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[244]新北市林口區公園路46號'), ('電話', '(02)26008457'), ('網址', 'http://www.lles.ntpc.edu.tw')])
# OrderedDict([('代碼', '014803'), ('學校名稱', '市立集美國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[241]新北市三重區集美街10號'), ('電話', '(02)89725390'), ('網址', 'http://www.jmes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014804'), ('學校名稱', '市立永吉國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[239]新北市鶯歌區德昌二街2號'), ('電話', '(02)26704177'), ('網址', 'http://www.yces.ntpc.edu.tw')])
# OrderedDict([('代碼', '014805'), ('學校名稱', '市立大崁國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[249]新北市八里區忠八街2號'), ('電話', '(02)86305678'), ('網址', 'http://www.tkes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014806'), ('學校名稱', '市立中園國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[237]新北市三峽區大同路222巷22弄2號'), ('電話', '(02)86712590'), ('網址', 'http://www.jyps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014807'), ('學校名稱', '市立昌福國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[239]新北市鶯歌區永明街22號'), ('電話', '(02)86773322'), ('網址', 'http://www.cfps.ntpc.edu.tw')])
# OrderedDict([('代碼', '014808'), ('學校名稱', '市立忠義國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[247]新北市蘆洲區光榮路99號'), ('電話', '(02)22899591'), ('網址', 'http://www.cyes.ntpc.edu.tw')])
# OrderedDict([('代碼', '014809'), ('學校名稱', '市立豐珠國(中)小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[228]新北市貢寮區美豐里雞母嶺街6-6號'), ('電話', '(02)24903727'), ('網址', 'http://www.fjjh.ntpc.edu.tw')])
# OrderedDict([('代碼', '014811'), ('學校名稱', '市立青山國(中)小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[221]新北市汐止區莊敬街33號'), ('電話', '(02)26917875'), ('網址', 'http://www.csjhs.ntpc.edu.tw')])
# OrderedDict([('代碼', '014812'), ('學校名稱', '市立義學國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[243]新北市泰山區民生路30號'), ('電話', '(02)22972048'), ('網址', 'http://www.yses.ntpc.edu.tw')])
# OrderedDict([('代碼', '014813'), ('學校名稱', '市立達觀國(中)小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[231]新北市新店區僑信路1號'), ('電話', '(02)22159013'), ('網址', 'http://www.dgejh.ntpc.edu.tw/default.asp')])
# OrderedDict([('代碼', '014814'), ('學校名稱', '市立桃子腳國(中)小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[238]新北市樹林區學勤路555號'), ('電話', '(02)89703225'), ('網址', 'http://www.tykjh.ntpc.edu.tw')])
# OrderedDict([('代碼', '014815'), ('學校名稱', '市立龍埔國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[237]新北市三峽區大學路6號'), ('電話', '(02)26745666'), ('網址', 'http://www.lpes.ntpc.edu.tw/default.asp')])
# OrderedDict([('代碼', '014816'), ('學校名稱', '市立頭湖國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[244]新北市林口區民權路101號'), ('電話', '(02)26080766'), ('網址', 'http://www.jles.ntpc.edu.tw/')])
# OrderedDict([('代碼', '014817'), ('學校名稱', '市立新市國小'), ('公/私立', '公立'), ('縣市名稱', '[01]新北市'), ('地址', '[251]新北市淡水區中山北路二段200號'), ('電話', '(02)26262141'), ('網址', 'http://www.xses.ntpc.edu.tw/default.asp')])
# OrderedDict([('代碼', '313601'), ('學校名稱', '市立松山國小'), ('公/私立', '公立'), ('縣市名稱', '[31]臺北市'), ('地址', '[105]臺北市松山區八德路四段746號'), ('電話', '(02)27672907'), ('網址', 'http://web.ssps.tp.edu.tw')])
# OrderedDict([('代碼', '313602'), ('學校名稱', '市立西松國小'), ('公/私立', '公立'), ('縣市名稱', '[31]臺北市'), ('地址', '[105]臺北市松山區東光里三民路5號'), ('電話', '(02)27609221'), ('網址', 'http://www.sups.tp.edu.tw')])
# OrderedDict([('代碼', '313604'), ('學校名稱', '市立敦化國小'), ('公/私立', '公立'), ('縣市名稱', '[31]臺北市'), ('地址', '[105]臺北市松山區中正里敦化北路2號'), ('電話', '(02)27414065'), ('網址', 'http://www.thps.tp.edu.tw')])
# OrderedDict([('代碼', '313605'), ('學校名稱', '市立民生國小'), ('公/私立', '公立'), ('縣市名稱', '[31]臺北市'), ('地址', '[105]臺北市松山區敦化北路199巷18號'), ('電話', '(02)27122452'), ('網址', 'http://www.msps.tp.edu.tw')])
# OrderedDict([('代碼', '313606'), ('學校名稱', '市立民權國小'), ('公/私立', '公立'), ('縣市名稱', '[31]臺北市'), ('地址', '[105]臺北市松山區民權東路四段200號'), ('電話', '(02)27652327'), ('網址', 'http://www.mcps.tp.edu.tw')])
# OrderedDict([('代碼', '313607'), ('學校名稱', '市立民族國小'), ('公/私立', '公立'), ('縣市名稱', '[31]臺北市'), ('地址', '[105]臺北市松山區民生東路4段97巷7號'), ('電話', '(02)27124872'), ('網址', 'http://epage.mces.tp.edu.tw/bin/home.php')])
# OrderedDict([('代碼', '313608'), ('學校名稱', '市立三民國小'), ('公/私立', '公立'), ('縣市名稱', '[31]臺北市'), ('地址', '[105]臺北市松山區莊敬里民權東路五段1號'), ('電話', '(02)27646080'), ('網址', 'http://www.smps.tp.edu.tw')])
# OrderedDict([('代碼', '313609'), ('學校名稱', '市立健康國小'), ('公/私立', '公立'), ('縣市名稱', '[31]臺北市'), ('地址', '[105]臺北市松山區延壽街168號'), ('電話', '(02)25282814'), ('網址', 'http://www.jkes.tp.edu.tw')])
# OrderedDict([('代碼', '323601'), ('學校名稱', '市立興雅國小'), ('公/私立', '公立'), ('縣市名稱', '[32]臺北市'), ('地址', '[110]臺北市信義區雅祥里基隆路1段83巷9號'), ('電話', '(02)27618156'), ('網址', 'http://www.hyps.tp.edu.tw')])
# OrderedDict([('代碼', '323602'), ('學校名稱', '市立永春國小'), ('公/私立', '公立'), ('縣市名稱', '[32]臺北市'), ('地址', '[110]臺北市信義區永春里松山路225巷48號'), ('電話', '(02)27641314'), ('網址', 'http://www.ycps.tp.edu.tw')])
# OrderedDict([('代碼', '323603'), ('學校名稱', '市立光復國小'), ('公/私立', '公立'), ('縣市名稱', '[32]臺北市'), ('地址', '[110]臺北市信義區光復南路271號'), ('電話', '(02)27585076'), ('網址', 'http://www.kfps.tp.edu.tw')])
# OrderedDict([('代碼', '323604'), ('學校名稱', '市立三興國小'), ('公/私立', '公立'), ('縣市名稱', '[32]臺北市'), ('地址', '[110]臺北市信義區景聯里基隆路2段99號'), ('電話', '(02)27385488'), ('網址', 'http://www.shps.tp.edu.tw')])
# OrderedDict([('代碼', '323605'), ('學校名稱', '市立信義國小'), ('公/私立', '公立'), ('縣市名稱', '[32]臺北市'), ('地址', '[110]臺北市信義區松勤街60號'), ('電話', '(02)27204005'), ('網址', 'http://www.syes.tp.edu.tw')])
# OrderedDict([('代碼', '323606'), ('學校名稱', '市立吳興國小'), ('公/私立', '公立'), ('縣市名稱', '[32]臺北市'), ('地址', '[110]臺北市信義區松仁路226號'), ('電話', '(02)27200226'), ('網址', 'http://www.wsps.tp.edu.tw/')])
# OrderedDict([('代碼', '323607'), ('學校名稱', '市立福德國小'), ('公/私立', '公立'), ('縣市名稱', '[32]臺北市'), ('地址', '[110]臺北市信義區中行里褔德街253號'), ('電話', '(02)27277992'), ('網址', 'http://www.fdps.tp.edu.tw')])
# OrderedDict([('代碼', '323608'), ('學校名稱', '市立永吉國小'), ('公/私立', '公立'), ('縣市名稱', '[32]臺北市'), ('地址', '[110]臺北市信義區永春里松山路287巷5號'), ('電話', '(02)87858111'), ('網址', 'http://www.yhps.tp.edu.tw')])
# OrderedDict([('代碼', '323609'), ('學校名稱', '市立博愛國小'), ('公/私立', '公立'), ('縣市名稱', '[32]臺北市'), ('地址', '[110]臺北市信義區松仁路22鄰95巷20號'), ('電話', '(02)23450616'), ('網址', 'http://www.baps.tp.edu.tw')])
# OrderedDict([('代碼', '330601'), ('學校名稱', '國立臺北教大實小'), ('公/私立', '公立'), ('縣市名稱', '[33]臺北市'), ('地址', '[106]臺北市大安區龍淵里和平東路2段94號'), ('電話', '(02)27356186'), ('網址', 'http://www.ntueees.tp.edu.tw/')])
# OrderedDict([('代碼', '331601'), ('學校名稱', '私立復興國小'), ('公/私立', '私立'), ('縣市名稱', '[33]臺北市'), ('地址', '[106]臺北市大安區仁愛里敦化南路1段262號'), ('電話', '(02)27715859'), ('網址', 'http://www.fhjh.tp.edu.tw')])
# OrderedDict([('代碼', '331602'), ('學校名稱', '私立立人國(中)小'), ('公/私立', '私立'), ('縣市名稱', '[33]臺北市'), ('地址', '[106]臺北市大安區義榮里安和路二段99號'), ('電話', '(02)27361388'), ('網址', 'http://www.ljjhps.tp.edu.tw')])
# OrderedDict([('代碼', '331603'), ('學校名稱', '私立新民小學'), ('公/私立', '私立'), ('縣市名稱', '[33]臺北市'), ('地址', '[106]臺北市大安區龍坡里辛亥路1段113號'), ('電話', '(02)23630450'), ('網址', 'http://www.hmps.tp.edu.tw')])
# OrderedDict([('代碼', '333601'), ('學校名稱', '市立龍安國小'), ('公/私立', '公立'), ('縣市名稱', '[33]臺北市'), ('地址', '[106]臺北市大安區龍門里新生南路3段33號'), ('電話', '(02)23632077'), ('網址', 'http://www.laes.tp.edu.tw')])
# OrderedDict([('代碼', '333602'), ('學校名稱', '市立大安國小'), ('公/私立', '公立'), ('縣市名稱', '[33]臺北市'), ('地址', '[106]臺北市大安區芳和里臥龍街129號'), ('電話', '(02)27322332'), ('網址', 'http://www.taes.tp.edu.tw')])
# OrderedDict([('代碼', '333603'), ('學校名稱', '市立幸安國小'), ('公/私立', '公立'), ('縣市名稱', '[33]臺北市'), ('地址', '[106]臺北市大安區民炤里仁愛路3段22號'), ('電話', '(02)27074191'), ('網址', 'http://www.haps.tp.edu.tw')])
# OrderedDict([('代碼', '333604'), ('學校名稱', '市立建安國小'), ('公/私立', '公立'), ('縣市名稱', '[33]臺北市'), ('地址', '[106]臺北市大安區龍雲里大安路2段99號'), ('電話', '(02)27077119'), ('網址', 'http://www.jnps.tp.edu.tw')])
# OrderedDict([('代碼', '333605'), ('學校名稱', '市立仁愛國小'), ('公/私立', '公立'), ('縣市名稱', '[33]臺北市'), ('地址', '[106]臺北市大安區敦安里安和路1段60號'), ('電話', '(02)27095010'), ('網址', 'http://www.japs.tp.edu.tw')])
# OrderedDict([('代碼', '333606'), ('學校名稱', '市立金華國小'), ('公/私立', '公立'), ('縣市名稱', '[33]臺北市'), ('地址', '[106]臺北市大安區永康里愛國東路79巷11號'), ('電話', '(02)23917402'), ('網址', 'http://www.cups.tp.edu.tw/./')])
# OrderedDict([('代碼', '333607'), ('學校名稱', '市立古亭國小'), ('公/私立', '公立'), ('縣市名稱', '[33]臺北市'), ('地址', '[106]臺北市大安區古風里羅斯福路3段201號'), ('電話', '(02)23639795'), ('網址', 'http://www.gtes.tp.edu.tw')])
# OrderedDict([('代碼', '333608'), ('學校名稱', '市立銘傳國小'), ('公/私立', '公立'), ('縣市名稱', '[33]臺北市'), ('地址', '[106]臺北市大安區農場里羅斯褔路四段21號'), ('電話', '(02)23639815'), ('網址', 'http://www.mhps.tp.edu.tw')])
# OrderedDict([('代碼', '333609'), ('學校名稱', '市立公館國小'), ('公/私立', '公立'), ('縣市名稱', '[33]臺北市'), ('地址', '[106]臺北市大安區基隆路4段41巷68弄2號'), ('電話', '(02)27351734'), ('網址', 'http://www.gges.tp.edu.tw')])
# OrderedDict([('代碼', '333610'), ('學校名稱', '市立新生國小'), ('公/私立', '公立'), ('縣市名稱', '[33]臺北市'), ('地址', '[106]臺北市大安區新生南路二段36號'), ('電話', '(02)23913122'), ('網址', 'http://www.snes.tp.edu.tw')])
# OrderedDict([('代碼', '333611'), ('學校名稱', '市立和平實驗國小'), ('公/私立', '公立'), ('縣市名稱', '[33]臺北市'), ('地址', '[106]臺北市大安區敦南街76巷28號'), ('電話', '(02)27335900'), ('網址', 'http://sites.google.com/site/hopingelschool/')])
# OrderedDict([('代碼', '343601'), ('學校名稱', '市立中山國小'), ('公/私立', '公立'), ('縣市名稱', '[34]臺北市'), ('地址', '[104]臺北市中山區恆安里民權東路1段69號'), ('電話', '(02)25914085'), ('網址', 'http://www.csps.tp.edu.tw')])
# OrderedDict([('代碼', '343602'), ('學校名稱', '市立中正國小'), ('公/私立', '公立'), ('縣市名稱', '[34]臺北市'), ('地址', '[104]臺北市中山區力行里龍江路62號'), ('電話', '(02)25070932'), ('網址', 'http://web.jjes.tp.edu.tw')])
# OrderedDict([('代碼', '343603'), ('學校名稱', '市立長安國小'), ('公/私立', '公立'), ('縣市名稱', '[34]臺北市'), ('地址', '[104]臺北市中山區興亞里吉林路15號'), ('電話', '(02)25617600'), ('網址', 'http://www.caps.tp.edu.tw')])
# OrderedDict([('代碼', '343604'), ('學校名稱', '市立長春國小'), ('公/私立', '公立'), ('縣市名稱', '[34]臺北市'), ('地址', '[104]臺北市中山區中央里長春路165號'), ('電話', '(02)25024366'), ('網址', 'http://www.ccps.tp.edu.tw')])
# OrderedDict([('代碼', '343605'), ('學校名稱', '市立大直國小'), ('公/私立', '公立'), ('縣市名稱', '[34]臺北市'), ('地址', '[104]臺北市中山區大直里大直街2號'), ('電話', '(02)25333953'), ('網址', 'http://www.tzes.tp.edu.tw')])
# OrderedDict([('代碼', '343606'), ('學校名稱', '市立大佳國小'), ('公/私立', '公立'), ('縣市名稱', '[34]臺北市'), ('地址', '[104]臺北市中山區大佳里6鄰濱江街107號'), ('電話', '(02)25035816'), ('網址', 'http://www.djes.tp.edu.tw')])
# OrderedDict([('代碼', '343607'), ('學校名稱', '市立五常國小'), ('公/私立', '公立'), ('縣市名稱', '[34]臺北市'), ('地址', '[104]臺北市中山區下埤里五常街16號'), ('電話', '(02)25023416'), ('網址', 'http://www.wcps.tp.edu.tw/enable01/index.php')])
# OrderedDict([('代碼', '343608'), ('學校名稱', '市立吉林國小'), ('公/私立', '公立'), ('縣市名稱', '[34]臺北市'), ('地址', '[104]臺北市中山區中原里長春路116號'), ('電話', '(02)25219196'), ('網址', 'http://www.clps.tp.edu.tw')])
# OrderedDict([('代碼', '343609'), ('學校名稱', '市立懷生國小'), ('公/私立', '公立'), ('縣市名稱', '[34]臺北市'), ('地址', '[104]臺北市中山區埤頭里安東街16巷2號'), ('電話', '(02)27710846'), ('網址', 'http://www.wses.tp.edu.tw')])
# OrderedDict([('代碼', '343610'), ('學校名稱', '市立永安國小'), ('公/私立', '公立'), ('縣市名稱', '[34]臺北市'), ('地址', '[104]臺北市中山區明水路397巷19弄1號'), ('電話', '(02)25335672'), ('網址', 'http://www.yaes.tp.edu.tw')])
# OrderedDict([('代碼', '343611'), ('學校名稱', '市立濱江國小'), ('公/私立', '公立'), ('縣市名稱', '[34]臺北市'), ('地址', '[104]臺北市中山區樂群二路266巷99號'), ('電話', '(02)85021571'), ('網址', 'http://www.bjes.tp.edu.tw')])
# OrderedDict([('代碼', '353601'), ('學校名稱', '市立螢橋國小'), ('公/私立', '公立'), ('縣市名稱', '[35]臺北市'), ('地址', '[100]臺北市中正區螢雪里詔安街29號'), ('電話', '(02)23054620'), ('網址', 'http://www.yces.tp.edu.tw')])
# OrderedDict([('代碼', '353602'), ('學校名稱', '市立河堤國小'), ('公/私立', '公立'), ('縣市名稱', '[35]臺北市'), ('地址', '[100]臺北市中正區汀州路二段180號'), ('電話', '(02)23677144'), ('網址', 'http://www.htps.tp.edu.tw')])
# ...
# OrderedDict([('代碼', '373605'), ('學校名稱', '市立西園國小'), ('公/私立', '公立'), ('縣市名稱', '[37]臺北市'), ('地址', '[108]臺北市萬華區日善里東園街73巷65號'), ('電話', '(02)23030257'), ('網址', 'http://www.hups.tp.edu.tw')])
# OrderedDict([('代碼', '373606'), ('學校名稱', '市立萬大國小'), ('公/私立', '公立'), ('縣市名稱', '[37]臺北市'), ('地址', '[108]臺北市萬華區全德里萬大路346號'), ('電話', '(02)23037654'), ('網址', 'http://www.wtps.tp.edu.tw')])
# OrderedDict([('代碼', '373607'), ('學校名稱', '市立華江國小'), ('公/私立', '公立'), ('縣市名稱', '[37]臺北市'), ('地址', '[108]臺北市萬華區環河南路2段250巷42弄2號'), ('電話', '(02)23064352'), ('網址', 'http://web.hces.tp.edu.tw/front/bin/home.phtml')])
# OrderedDict([('代碼', '373608'), ('學校名稱', '市立西門國小'), ('公/私立', '公立'), ('縣市名稱', '[37]臺北市'), ('地址', '[108]臺北市萬華區西門里成都路98號'), ('電話', '(02)23113519'), ('網址', 'http://www.hmes.tp.edu.tw')])
# OrderedDict([('代碼', '373609'), ('學校名稱', '市立老松國小'), ('公/私立', '公立'), ('縣市名稱', '[37]臺北市'), ('地址', '[108]臺北市萬華區福音里桂林路64號'), ('電話', '(02)23361266'), ('網址', 'http://www.tlsps.tp.edu.tw')])
# OrderedDict([('代碼', '373610'), ('學校名稱', '市立龍山國小'), ('公/私立', '公立'), ('縣市名稱', '[37]臺北市'), ('地址', '[108]臺北市萬華區青山里和平西路三段235號'), ('電話', '(02)23082977'), ('網址', 'http://www.lses.tp.edu.tw')])
# OrderedDict([('代碼', '373611'), ('學校名稱', '市立福星國小'), ('公/私立', '公立'), ('縣市名稱', '[37]臺北市'), ('地址', '[108]臺北市萬華區福星里中華路一段66號'), ('電話', '(02)23144668'), ('網址', 'http://www.fhps.tp.edu.tw')])
# OrderedDict([('代碼', '380601'), ('學校名稱', '國立政大實小'), ('公/私立', '公立'), ('縣市名稱', '[38]臺北市'), ('地址', '[116]臺北市文山區指南路三段12號'), ('電話', '(02)29393610'), ('網址', 'http://www.es.nccu.edu.tw')])
# OrderedDict([('代碼', '381601'), ('學校名稱', '私立靜心小學'), ('公/私立', '私立'), ('縣市名稱', '[38]臺北市'), ('地址', '[116]臺北市文山區興福里興隆路2段46號'), ('電話', '(02)29323118'), ('網址', 'http://www.chjhs.tp.edu.tw')])
# OrderedDict([('代碼', '381602'), ('學校名稱', '私立中山小學'), ('公/私立', '私立'), ('縣市名稱', '[38]臺北市'), ('地址', '[116]臺北市文山區木柵路1段292號'), ('電話', '(02)29360935'), ('網址', 'http://www.mjcskg.tp.edu.tw')])
# OrderedDict([('代碼', '381603'), ('學校名稱', '私立再興小學'), ('公/私立', '私立'), ('縣市名稱', '[38]臺北市'), ('地址', '[116]臺北市文山區明義里興隆路4段2號'), ('電話', '(02)29371118'), ('網址', 'http://www.thsh.tp.edu.tw/web/TSPS')])
# OrderedDict([('代碼', '383601'), ('學校名稱', '市立景美國小'), ('公/私立', '公立'), ('縣市名稱', '[38]臺北市'), ('地址', '[116]臺北市文山區景行里景文街108號'), ('電話', '(02)29322151'), ('網址', 'http://www.cmes.tp.edu.tw')])
# OrderedDict([('代碼', '383602'), ('學校名稱', '市立武功國小'), ('公/私立', '公立'), ('縣市名稱', '[38]臺北市'), ('地址', '[116]臺北市文山區萬祥里興隆路1段68號'), ('電話', '(02)29314360'), ('網址', 'http://www.wkps.tp.edu.tw')])
# OrderedDict([('代碼', '383603'), ('學校名稱', '市立興德國小'), ('公/私立', '公立'), ('縣市名稱', '[38]臺北市'), ('地址', '[116]臺北市文山區興邦里興隆路2段235號'), ('電話', '(02)29329431'), ('網址', 'http://www.hdps.tp.edu.tw')])
# OrderedDict([('代碼', '383604'), ('學校名稱', '市立溪口國小'), ('公/私立', '公立'), ('縣市名稱', '[38]臺北市'), ('地址', '[116]臺北市文山區景慶里景福街225號'), ('電話', '(02)29350955'), ('網址', 'http://web.skps.tp.edu.tw/enableweb/')])
# OrderedDict([('代碼', '383605'), ('學校名稱', '市立興隆國小'), ('公/私立', '公立'), ('縣市名稱', '[38]臺北市'), ('地址', '[116]臺北市文山區興望里福興路2號'), ('電話', '(02)29323131'), ('網址', 'http://www.hlps.tp.edu.tw')])
# OrderedDict([('代碼', '383606'), ('學校名稱', '市立志清國小'), ('公/私立', '公立'), ('縣市名稱', '[38]臺北市'), ('地址', '[116]臺北市文山區景仁里景福街21巷5號'), ('電話', '(02)29323875'), ('網址', 'http://www.jcps.tp.edu.tw')])
# OrderedDict([('代碼', '383607'), ('學校名稱', '市立景興國小'), ('公/私立', '公立'), ('縣市名稱', '[38]臺北市'), ('地址', '[116]臺北市文山區興安里景華街150巷21號'), ('電話', '(02)29329439'), ('網址', 'http://www.chps.tp.edu.tw')])
# OrderedDict([('代碼', '383608'), ('學校名稱', '市立木柵國小'), ('公/私立', '公立'), ('縣市名稱', '[38]臺北市'), ('地址', '[116]臺北市文山區木柵里木柵路3段191號'), ('電話', '(02)29391234'), ('網址', 'http://www.mjes.tp.edu.tw')])
# OrderedDict([('代碼', '383609'), ('學校名稱', '市立永建國小'), ('公/私立', '公立'), ('縣市名稱', '[38]臺北市'), ('地址', '[116]臺北市文山區華興里試院路2號'), ('電話', '(02)22363855'), ('網址', 'http://www.yjps.tp.edu.tw')])
# OrderedDict([('代碼', '383610'), ('學校名稱', '市立實踐國小'), ('公/私立', '公立'), ('縣市名稱', '[38]臺北市'), ('地址', '[116]臺北市文山區樟文里忠順街1段4號'), ('電話', '(02)29360725'), ('網址', 'http://www.zjps.tp.edu.tw')])
# OrderedDict([('代碼', '383611'), ('學校名稱', '市立博嘉國小'), ('公/私立', '公立'), ('縣市名稱', '[38]臺北市'), ('地址', '[116]臺北市文山區木柵路4段159巷14-1號'), ('電話', '(02)22302585'), ('網址', 'http://www.bjps.tp.edu.tw')])
# OrderedDict([('代碼', '383612'), ('學校名稱', '市立指南國小'), ('公/私立', '公立'), ('縣市名稱', '[38]臺北市'), ('地址', '[116]臺北市文山區指南路三段38巷5-2號'), ('電話', '(02)29393546'), ('網址', 'http://www.cnps.tp.edu.tw')])
# OrderedDict([('代碼', '383613'), ('學校名稱', '市立明道國小'), ('公/私立', '公立'), ('縣市名稱', '[38]臺北市'), ('地址', '[116]臺北市文山區明興里木柵路2段138巷61號'), ('電話', '(02)29392821'), ('網址', 'http://www.mdps.tp.edu.tw')])
# OrderedDict([('代碼', '383614'), ('學校名稱', '市立萬芳國小'), ('公/私立', '公立'), ('縣市名稱', '[38]臺北市'), ('地址', '[116]臺北市文山區萬芳里萬和街1號'), ('電話', '(02)22301232'), ('網址', 'http://www.wfes.tp.edu.tw')])
# OrderedDict([('代碼', '383615'), ('學校名稱', '市立力行國小'), ('公/私立', '公立'), ('縣市名稱', '[38]臺北市'), ('地址', '[116]臺北市文山區樟腳里木新路3段155巷7號'), ('電話', '(02)29363995'), ('網址', 'http://www.lsps.tp.edu.tw')])
# OrderedDict([('代碼', '383616'), ('學校名稱', '市立萬興國小'), ('公/私立', '公立'), ('縣市名稱', '[38]臺北市'), ('地址', '[116]臺北市文山區萬興里秀明路2段114號'), ('電話', '(02)29381721'), ('網址', 'http://www.wnses.tp.edu.tw')])
# OrderedDict([('代碼', '383617'), ('學校名稱', '市立萬福國小'), ('公/私立', '公立'), ('縣市名稱', '[38]臺北市'), ('地址', '[116]臺北市文山區羅斯福路5段170巷32號'), ('電話', '(02)29353123'), ('網址', 'http://www.wfps.tp.edu.tw')])
# OrderedDict([('代碼', '383618'), ('學校名稱', '市立興華國小'), ('公/私立', '公立'), ('縣市名稱', '[38]臺北市'), ('地址', '[116]臺北市文山區興光里興隆路3段125巷6號'), ('電話', '(02)22393070'), ('網址', 'http://www.hhps.tp.edu.tw')])
# OrderedDict([('代碼', '383619'), ('學校名稱', '市立辛亥國小'), ('公/私立', '公立'), ('縣市名稱', '[38]臺北市'), ('地址', '[116]臺北市文山區興昌里辛亥路4段103號'), ('電話', '(02)29357282'), ('網址', 'http://www.saes.tp.edu.tw')])
# OrderedDict([('代碼', '393601'), ('學校名稱', '市立南港國小'), ('公/私立', '公立'), ('縣市名稱', '[39]臺北市'), ('地址', '[115]臺北市南港區三重里惠民街67號'), ('電話', '(02)27834678'), ('網址', 'http://www.nkps.tp.edu.tw')])
# OrderedDict([('代碼', '393602'), ('學校名稱', '市立舊莊國小'), ('公/私立', '公立'), ('縣市名稱', '[39]臺北市'), ('地址', '[115]臺北市南港區舊莊里舊莊街1段100號'), ('電話', '(02)27821418'), ('網址', 'http://www.zzes.tp.edu.tw')])
# OrderedDict([('代碼', '393603'), ('學校名稱', '市立玉成國小'), ('公/私立', '公立'), ('縣市名稱', '[39]臺北市'), ('地址', '[115]臺北市南港區西新里向陽路31號'), ('電話', '(02)27836049'), ('網址', 'http://www.yhes.tp.edu.tw')])
# OrderedDict([('代碼', '393604'), ('學校名稱', '市立成德國小'), ('公/私立', '公立'), ('縣市名稱', '[39]臺北市'), ('地址', '[115]臺北市南港區聯成里東新街65號'), ('電話', '(02)27851376'), ('網址', 'http://www.ctps.tp.edu.tw')])
# OrderedDict([('代碼', '393605'), ('學校名稱', '市立胡適國小'), ('公/私立', '公立'), ('縣市名稱', '[39]臺北市'), ('地址', '[115]臺北市南港區中研里舊莊街1段1號'), ('電話', '(02)27824949'), ('網址', 'http://www.hsps.tp.edu.tw')])
# OrderedDict([('代碼', '393606'), ('學校名稱', '市立東新國小'), ('公/私立', '公立'), ('縣市名稱', '[39]臺北市'), ('地址', '[115]臺北市南港區東新里興南街62號'), ('電話', '(02)27837577'), ('網址', 'http://www.thes.tp.edu.tw')])
# OrderedDict([('代碼', '393607'), ('學校名稱', '市立修德國小'), ('公/私立', '公立'), ('縣市名稱', '[39]臺北市'), ('地址', '[115]臺北市南港區東新街118巷86號'), ('電話', '(02)27880500'), ('網址', 'http://www.sdps.tp.edu.tw')])
# OrderedDict([('代碼', '403601'), ('學校名稱', '市立內湖國小'), ('公/私立', '公立'), ('縣市名稱', '[40]臺北市'), ('地址', '[114]臺北市內湖區港富里內湖路二段41號'), ('電話', '(02)27998085'), ('網址', 'http://www.nhes.tp.edu.tw')])
# OrderedDict([('代碼', '403602'), ('學校名稱', '市立碧湖國小'), ('公/私立', '公立'), ('縣市名稱', '[40]臺北市'), ('地址', '[114]臺北市內湖區內湖里金龍路100號'), ('電話', '(02)27907161'), ('網址', 'http://www.bhps.tp.edu.tw')])
# OrderedDict([('代碼', '403603'), ('學校名稱', '市立潭美國小'), ('公/私立', '公立'), ('縣市名稱', '[40]臺北市'), ('地址', '[114]臺北市內湖區石潭里新明路22號'), ('電話', '(02)27917334'), ('網址', 'http://www.tmes.tp.edu.tw')])
# OrderedDict([('代碼', '403604'), ('學校名稱', '市立東湖國小'), ('公/私立', '公立'), ('縣市名稱', '[40]臺北市'), ('地址', '[114]臺北市內湖區東湖里東湖路115號'), ('電話', '(02)26339984'), ('網址', 'http://w3.dfps.tp.edu.tw')])
# OrderedDict([('代碼', '403605'), ('學校名稱', '市立西湖國小'), ('公/私立', '公立'), ('縣市名稱', '[40]臺北市'), ('地址', '[114]臺北市內湖區西湖里環山路1段25號'), ('電話', '(02)27971267'), ('網址', 'http://www.hhups.tp.edu.tw')])
# OrderedDict([('代碼', '403606'), ('學校名稱', '市立康寧國小'), ('公/私立', '公立'), ('縣市名稱', '[40]臺北市'), ('地址', '[114]臺北市內湖區清白里星雲街121號'), ('電話', '(02)27901237'), ('網址', 'http://www.klps.tp.edu.tw')])
# OrderedDict([('代碼', '403607'), ('學校名稱', '市立明湖國小'), ('公/私立', '公立'), ('縣市名稱', '[40]臺北市'), ('地址', '[114]臺北市內湖區東湖里康寧路3段105號'), ('電話', '(02)26323477'), ('網址', 'http://www.mhups.tp.edu.tw')])
# OrderedDict([('代碼', '403608'), ('學校名稱', '市立麗山國小'), ('公/私立', '公立'), ('縣市名稱', '[40]臺北市'), ('地址', '[114]臺北市內湖區港都里港華街100號'), ('電話', '(02)26574158'), ('網址', 'http://www.lnps.tp.edu.tw')])
# OrderedDict([('代碼', '403609'), ('學校名稱', '市立新湖國小'), ('公/私立', '公立'), ('縣市名稱', '[40]臺北市'), ('地址', '[114]臺北市內湖區湖興里民權東路6段138號'), ('電話', '(02)27963721'), ('網址', 'http://www.shes.tp.edu.tw')])
# OrderedDict([('代碼', '403610'), ('學校名稱', '市立文湖國小'), ('公/私立', '公立'), ('縣市名稱', '[40]臺北市'), ('地址', '[114]臺北市內湖區西康里文湖街15號'), ('電話', '(02)26583515'), ('網址', 'http://www.whups.tp.edu.tw')])
# OrderedDict([('代碼', '403611'), ('學校名稱', '市立大湖國小'), ('公/私立', '公立'), ('縣市名稱', '[40]臺北市'), ('地址', '[114]臺北市內湖區大湖里大湖山莊街170號'), ('電話', '(02)27915870'), ('網址', 'http://www.dhps.tp.edu.tw')])
# OrderedDict([('代碼', '403612'), ('學校名稱', '市立南湖國小'), ('公/私立', '公立'), ('縣市名稱', '[40]臺北市'), ('地址', '[114]臺北市內湖區葫洲里康寧路3段200號'), ('電話', '(02)26321296'), ('網址', 'http://www.nhps.tp.edu.tw')])
# OrderedDict([('代碼', '403613'), ('學校名稱', '市立麗湖國小'), ('公/私立', '公立'), ('縣市名稱', '[40]臺北市'), ('地址', '[114]臺北市內湖區金湖路363巷8號'), ('電話', '(02)26343888'), ('網址', 'http://www.lhes.tp.edu.tw/')])
# OrderedDict([('代碼', '411601'), ('學校名稱', '私立華興小學'), ('公/私立', '私立'), ('縣市名稱', '[41]臺北市'), ('地址', '[111]臺北市士林區芝山里仰德大道1段101號'), ('電話', '(02)28316834'), ('網址', 'http://www.hhhs.tp.edu.tw')])
# OrderedDict([('代碼', '413601'), ('學校名稱', '市立士林國小'), ('公/私立', '公立'), ('縣市名稱', '[41]臺北市'), ('地址', '[111]臺北市士林區福德里大東路165號'), ('電話', '(02)28812231'), ('網址', 'http://www.slps.tp.edu.tw')])
# OrderedDict([('代碼', '413602'), ('學校名稱', '市立士東國小'), ('公/私立', '公立'), ('縣市名稱', '[41]臺北市'), ('地址', '[111]臺北市士林區蘭雅里中山北路6段392號'), ('電話', '(02)28710064'), ('網址', 'http://www.stes.tp.edu.tw')])
# OrderedDict([('代碼', '413603'), ('學校名稱', '市立福林國小'), ('公/私立', '公立'), ('縣市名稱', '[41]臺北市'), ('地址', '[111]臺北市士林區福志里福志路75號'), ('電話', '(02)28316293'), ('網址', 'http://www.flps.tp.edu.tw')])
# OrderedDict([('代碼', '413604'), ('學校名稱', '市立陽明山國小'), ('公/私立', '公立'), ('縣市名稱', '[41]臺北市'), ('地址', '[111]臺北市士林區新安里仰德大道3段61號'), ('電話', '(02)28616366'), ('網址', 'http://www.ymps.tp.edu.tw')])
# OrderedDict([('代碼', '413605'), ('學校名稱', '市立社子國小'), ('公/私立', '公立'), ('縣市名稱', '[41]臺北市'), ('地址', '[111]臺北市士林區永倫里延平北路六段308號'), ('電話', '(02)28126195'), ('網址', 'http://www.stps.tp.edu.tw')])
# OrderedDict([('代碼', '413606'), ('學校名稱', '市立雨聲國小'), ('公/私立', '公立'), ('縣市名稱', '[41]臺北市'), ('地址', '[111]臺北市士林區岩山里至誠路1段62巷70號'), ('電話', '(02)28311004'), ('網址', 'http://www.yses.tp.edu.tw')])
# OrderedDict([('代碼', '413607'), ('學校名稱', '市立富安國小'), ('公/私立', '公立'), ('縣市名稱', '[41]臺北市'), ('地址', '[111]臺北市士林區富洲里延平北路8段135號'), ('電話', '(02)28103192'), ('網址', 'http://www.fuanps.tp.edu.tw')])
# OrderedDict([('代碼', '413608'), ('學校名稱', '市立劍潭國小'), ('公/私立', '公立'), ('縣市名稱', '[41]臺北市'), ('地址', '[111]臺北市士林區明勝里通河街16號'), ('電話', '(02)28855491'), ('網址', 'http://www.jtes.tp.edu.tw')])
# OrderedDict([('代碼', '413609'), ('學校名稱', '市立溪山國小'), ('公/私立', '公立'), ('縣市名稱', '[41]臺北市'), ('地址', '[111]臺北市士林區溪山里至善路3段199號'), ('電話', '(02)28411010'), ('網址', 'http://www.hops.tp.edu.tw')])
# OrderedDict([('代碼', '413610'), ('學校名稱', '市立平等國小'), ('公/私立', '公立'), ('縣市名稱', '[41]臺北市'), ('地址', '[111]臺北市士林區平等里平菁街101號'), ('電話', '(02)28610503'), ('網址', 'http://www.pdps.tp.edu.tw')])
# OrderedDict([('代碼', '413611'), ('學校名稱', '市立百齡國小'), ('公/私立', '公立'), ('縣市名稱', '[41]臺北市'), ('地址', '[111]臺北市士林區福中里福港街205號'), ('電話', '(02)28817683'), ('網址', 'http://www.bles.tp.edu.tw')])
# OrderedDict([('代碼', '413612'), ('學校名稱', '市立雙溪國小'), ('公/私立', '公立'), ('縣市名稱', '[41]臺北市'), ('地址', '[111]臺北市士林區翠山里中社路2段66號'), ('電話', '(02)28411038'), ('網址', 'http://www.sses.tp.edu.tw')])
# OrderedDict([('代碼', '413613'), ('學校名稱', '市立葫蘆國小'), ('公/私立', '公立'), ('縣市名稱', '[41]臺北市'), ('地址', '[111]臺北市士林區環河北路3段95號'), ('電話', '(02)28129586'), ('網址', 'http://www.hrps.tp.edu.tw')])
# OrderedDict([('代碼', '413614'), ('學校名稱', '市立雨農國小'), ('公/私立', '公立'), ('縣市名稱', '[41]臺北市'), ('地址', '[111]臺北市士林區名山里忠義街1號'), ('電話', '(02)28329700'), ('網址', 'http://www.ynes.tp.edu.tw/enable2007/')])
# OrderedDict([('代碼', '413615'), ('學校名稱', '市立天母國小'), ('公/私立', '公立'), ('縣市名稱', '[41]臺北市'), ('地址', '[111]臺北市士林區天玉里天玉街12號'), ('電話', '(02)28723336'), ('網址', 'http://www.tmups.tp.edu.tw')])
# OrderedDict([('代碼', '413616'), ('學校名稱', '市立文昌國小'), ('公/私立', '公立'), ('縣市名稱', '[41]臺北市'), ('地址', '[111]臺北市士林區文林路615巷20號'), ('電話', '(02)28365411'), ('網址', 'http://www.wces.tp.edu.tw')])
# OrderedDict([('代碼', '413617'), ('學校名稱', '市立芝山國小'), ('公/私立', '公立'), ('縣市名稱', '[41]臺北市'), ('地址', '[111]臺北市士林區芝山里德行東路285號'), ('電話', '(02)28316115'), ('網址', 'http://www.zsps.tp.edu.tw')])
# OrderedDict([('代碼', '413618'), ('學校名稱', '市立蘭雅國小'), ('公/私立', '公立'), ('縣市名稱', '[41]臺北市'), ('地址', '[111]臺北市士林區蘭興里磺溪街57號'), ('電話', '(02)28366052'), ('網址', 'http://www.lyps.tp.edu.tw')])
# OrderedDict([('代碼', '413619'), ('學校名稱', '市立三玉國小'), ('公/私立', '公立'), ('縣市名稱', '[41]臺北市'), ('地址', '[111]臺北市士林區三玉里天母東路116號'), ('電話', '(02)28751369'), ('網址', 'http://www.syups.tp.edu.tw')])
# OrderedDict([('代碼', '421601'), ('學校名稱', '私立薇閣小學'), ('公/私立', '私立'), ('縣市名稱', '[42]臺北市'), ('地址', '[112]臺北市北投區長安里育仁路106號'), ('電話', '(02)28912668'), ('網址', 'http://www.wgps.tp.edu.tw')])
# OrderedDict([('代碼', '423601'), ('學校名稱', '市立北投國小'), ('公/私立', '公立'), ('縣市名稱', '[42]臺北市'), ('地址', '[112]臺北市北投區長安里中央北路1段73號'), ('電話', '(02)28912052'), ('網址', 'http://www.ptes.tp.edu.tw')])
# OrderedDict([('代碼', '423602'), ('學校名稱', '市立逸仙國小'), ('公/私立', '公立'), ('縣市名稱', '[42]臺北市'), ('地址', '[112]臺北市北投區中心里新民路2號'), ('電話', '(02)28914537'), ('網址', 'http://www.ysps.tp.edu.tw')])
# OrderedDict([('代碼', '423603'), ('學校名稱', '市立石牌國小'), ('公/私立', '公立'), ('縣市名稱', '[42]臺北市'), ('地址', '[112]臺北市北投區吉利里致遠二路80號'), ('電話', '(02)28227484'), ('網址', 'http://web.spps.tp.edu.tw')])
# OrderedDict([('代碼', '423604'), ('學校名稱', '市立關渡國小'), ('公/私立', '公立'), ('縣市名稱', '[42]臺北市'), ('地址', '[112]臺北市北投區一德里中央北路4段581號'), ('電話', '(02)28912847'), ('網址', 'http://www.kdps.tp.edu.tw')])
# OrderedDict([('代碼', '423605'), ('學校名稱', '市立湖田國小'), ('公/私立', '公立'), ('縣市名稱', '[42]臺北市'), ('地址', '[112]臺北市北投區湖田里竹子湖路17之2號'), ('電話', '(02)28616963'), ('網址', 'http://www.htes.tp.edu.tw')])
# OrderedDict([('代碼', '423606'), ('學校名稱', '市立清江國小'), ('公/私立', '公立'), ('縣市名稱', '[42]臺北市'), ('地址', '[112]臺北市北投區奇岩里公館路220號'), ('電話', '(02)28912764'), ('網址', 'http://www.cjps.tp.edu.tw')])
# OrderedDict([('代碼', '423607'), ('學校名稱', '市立泉源國小'), ('公/私立', '公立'), ('縣市名稱', '[42]臺北市'), ('地址', '[112]臺北市北投區泉源里東昇路34號'), ('電話', '(02)28951258'), ('網址', 'http://www.cyps.tp.edu.tw')])
# OrderedDict([('代碼', '423608'), ('學校名稱', '市立大屯國小'), ('公/私立', '公立'), ('縣市名稱', '[42]臺北市'), ('地址', '[112]臺北市北投區大屯里復興三路312號'), ('電話', '(02)28914353'), ('網址', 'http://www.dtps.tp.edu.tw')])
# OrderedDict([('代碼', '423609'), ('學校名稱', '市立湖山國小'), ('公/私立', '公立'), ('縣市名稱', '[42]臺北市'), ('地址', '[112]臺北市北投區湖山里湖底路11號'), ('電話', '(02)28610148'), ('網址', 'http://www.hses.tp.edu.tw')])
# OrderedDict([('代碼', '423610'), ('學校名稱', '市立桃源國小'), ('公/私立', '公立'), ('縣市名稱', '[42]臺北市'), ('地址', '[112]臺北市北投區中央北路3段40巷45號'), ('電話', '(02)28941208'), ('網址', 'http://www.tyues.tp.edu.tw')])
# OrderedDict([('代碼', '423611'), ('學校名稱', '市立文林國小'), ('公/私立', '公立'), ('縣市名稱', '[42]臺北市'), ('地址', '[112]臺北市北投區建民里文林北路155號'), ('電話', '(02)28234212'), ('網址', 'http://www.wles.tp.edu.tw')])
# OrderedDict([('代碼', '423612'), ('學校名稱', '市立義方國小'), ('公/私立', '公立'), ('縣市名稱', '[42]臺北市'), ('地址', '[112]臺北市北投區珠海路155號'), ('電話', '(02)28917433'), ('網址', 'http://www.yfes.tp.edu.tw')])
# OrderedDict([('代碼', '423613'), ('學校名稱', '市立立農國小'), ('公/私立', '公立'), ('縣市名稱', '[42]臺北市'), ('地址', '[112]臺北市北投區立農里立農街1段250號'), ('電話', '(02)28210702'), ('網址', 'http://www.lnes.tp.edu.tw')])
# OrderedDict([('代碼', '423614'), ('學校名稱', '市立明德國小'), ('公/私立', '公立'), ('縣市名稱', '[42]臺北市'), ('地址', '[112]臺北市北投區榮華里明德路190號'), ('電話', '(02)28229651'), ('網址', 'http://www.mdes.tp.edu.tw')])
# OrderedDict([('代碼', '423616'), ('學校名稱', '市立文化國小'), ('公/私立', '公立'), ('縣市名稱', '[42]臺北市'), ('地址', '[112]臺北市北投區文化里文化三路1號'), ('電話', '(02)28933828'), ('網址', 'http://www.whps.tp.edu.tw')])

# %%
# %%time
import numpy as np
import pandas as pd
path = './school/'

df = pd.read_csv(file)
# Out:
# Wall time: 20.6 ms

# %%
df['縣市名稱'].unique()[0:13]
# Out:
# array(['[01]新北市', '[31]臺北市', '[32]臺北市', '[33]臺北市', '[34]臺北市', '[35]臺北市',
#        '[36]臺北市', '[37]臺北市', '[38]臺北市', '[39]臺北市', '[40]臺北市', '[41]臺北市',
#        '[42]臺北市'], dtype=object)

# %%
import requests

geocodeKey = 'AIzaSyB7p3YD8vA53GsueZ12bKEANpzXltx0xc0'
apiurl = 'https://maps.googleapis.com/maps/api/geocode/json'
queryData = {'address':'', 'key':geocodeKey}
queryData['address'] = '[220]新北市板橋區黃石里文化路一段23號'

res = requests.get(apiurl, params=queryData)

# %%
temp = {}
code = res.json()
if code.get('status') == 'OK':
    temp.update(code['results'][0]['geometry']['location'])
else:
    print(code.get('status'))

# %%
import Geocode as gmap
gmap.geocoding('[220]新北市板橋區黃石里文化路一段23號')
# Out:
# {'lat': 25.0108477, 'lng': 121.4582632}

# %%
import re
test = '[220]新北市板橋區黃石里文化路一段23號'

# %%
re.findall('\[(\d{3})\]',test)[0]
# Out:
# '220'
