# %% [markdown]
# # renthouse
# https://rent.housefun.com.tw

# %%
import requests
import json
url = 'https://rent.housefun.com.tw/region/%E5%8F%B0%E5%8C%97%E5%B8%82/?cid=0000'

header = {'User-Agent':'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36'}


res = requests.get(url, headers=header)

res.text
# Out:
# '\r\n\r\n<!DOCTYPE HTML>\r\n<!--[if lt IE 7]><html class="no-js IE" lang="en"><![endif]-->\r\n<!--[if IE 7]><html class="no-js IE7" lang="en"><![endif]-->\r\n<!--[if IE 8]><html class="no-js IE8" lang="en"><![endif]-->\r\n<!--[if gt IE 8]><!-->\r\n\r\n<html xmlns="http://www.w3.org/1999/xhtml" dir="ltr" lang="zh-Hant-TW" xmlns:og="http://opengraphprotocol.org/schema/" xmlns:fb="http://ogp.me/ns/fb#" itemscope itemtype="http://schema.org/" xmlns:wb="http://open.weibo.com/wb" class="no-js smart">\r\n<!--<![endif]-->\r\n<head><title>\r\n\t台北市租屋,租房子 | 在好房Housefun，輕鬆租好屋 | 好房快租\r\n</title><meta name="format-detection" content="telephone=no" /><meta http-equiv="Content-Type" content="text/html; charset=utf-8" /><meta http-equiv="X-UA-Compatible" content="IE=EmulateIE8,Edge" /><meta name="SKYPE_TOOLBAR" content="SKYPE_TOOLBAR_PARSER_COMPATIBLE" /><meta property="og:locale" content="zh_TW" /><meta id="mp_meta_title" name="title" property="og:title" itemprop="name" content="台北市租屋,租房子 | 在好房Hous
# ...

# %%
rent = 'https://rent.housefun.com.tw/rent/house/1290172/'
rent_res = requests.get(rent,headers=header)
rent_res.text
# Out:
# '\r\n\r\n<!DOCTYPE HTML>\r\n<!--[if lt IE 7]><html class="no-js IE" lang="en"><![endif]-->\r\n<!--[if IE 7]><html class="no-js IE7" lang="en"><![endif]-->\r\n<!--[if IE 8]><html class="no-js IE8" lang="en"><![endif]-->\r\n<!--[if gt IE 8]><!-->\r\n\r\n<html xmlns="http://www.w3.org/1999/xhtml" dir="ltr" lang="zh-Hant-TW" xmlns:og="http://opengraphprotocol.org/schema/" xmlns:fb="http://ogp.me/ns/fb#" itemscope itemtype="http://schema.org/" xmlns:wb="http://open.weibo.com/wb" class="no-js smart">\r\n<!--<![endif]-->\r\n<head><title>\r\n\t國家元首~有裝潢屋況優，2+1房，全套家具 | 好房快租\r\n</title><meta name="format-detection" content="telephone=no" /><meta http-equiv="Content-Type" content="text/html; charset=utf-8" /><meta http-equiv="X-UA-Compatible" content="IE=EmulateIE8,Edge" /><meta name="SKYPE_TOOLBAR" content="SKYPE_TOOLBAR_PARSER_COMPATIBLE" /><meta property="og:locale" content="zh_TW" /><meta id="mp_meta_title" name="title" property="og:title" itemprop="name" content="國家元首~有裝潢屋況優，2+1房，全套家具 | 好房快
# ...

# %%
import json 

formData = """{"Method":"VVBEQVRF","Data":{"DataUnit":"MQ==","DataType":"","DataTab":"","OrderBy":"","OrderType":"","CityId":"MDAwMA==","CityId2":"MDAwMQ==","CityId3":"","CityName":"5Y+w5YyX5biC","CityName2":"5paw5YyX5biC","CityName3":"","AreaId":"","AreaId2":"","AreaId3":"","AreaName":"","AreaName2":"","AreaName3":"","PurposeID":"MiwzLDQ=","PriceRental":"","PriceL":"","PriceH":"","MRTLine":"","MRTLine2":"","MRTLine3":"","MRTLineName":"","MRTLineName2":"","MRTLineName3":"","MRTStation":"","MRTStation2":"","MRTStation3":"","MRTStationName":"","MRTStationName2":"","MRTStationName3":"","SchoolType":"","SchoolTypeName":"","SchoolId":"","SchoolName":"","BuildingID":"","BuildingName":"","KeyWord":"","KWkind":"","KWID":"","KWCounty":"","KWDistrict":"","NotRequiredOtherFeeID":"","NotRequiredEquipmentID":"","NotRequiredBaseMent":"","Room":"","LevelGroundID":"","CaseTypeID":"","AgentPositionID":"","CaseFromFloor":"","CaseToFloor":"","BuildYear":"","BuildYearL":"","BuildYearH":"","chkOTLimSex":"","OTLimSex":"","OTParkingSpace":"","OTLimWithLandlord":"","OTLimPet":"","TGType":"","EquipmentID":"","PMPage":"MQ==","BrowseMode":"","CenterLat":"","CenterLng":"","SID":"","Distance":"","SearchList":"5Y+w5YyX5biC","MemberID":"","MainShopID":"","AgentName":"","LandlordNo":""}}"""

data = json.loads(formData)
data
# Out:
# {'Data': {'AgentName': '',
#   'AgentPositionID': '',
#   'AreaId': '',
#   'AreaId2': '',
#   'AreaId3': '',
#   'AreaName': '',
#   'AreaName2': '',
#   'AreaName3': '',
#   'BrowseMode': '',
#   'BuildYear': '',
#   'BuildYearH': '',
#   'BuildYearL': '',
#   'BuildingID': '',
#   'BuildingName': '',
#   'CaseFromFloor': '',
#   'CaseToFloor': '',
#   'CaseTypeID': '',
#   'CenterLat': '',
#   'CenterLng': '',
#   'CityId': 'MDAwMA==',
#   'CityId2': 'MDAwMQ==',
#   'CityId3': '',
#   'CityName': '5Y+w5YyX5biC',
#   'CityName2': '5paw5YyX5biC',
#   'CityName3': '',
#   'DataTab': '',
#   'DataType': '',
#   'DataUnit': 'MQ==',
#   'Distance': '',
#   'EquipmentID': '',
#   'KWCounty': '',
#   'KWDistrict': '',
#   'KWID': '',
#   'KWkind': '',
#   'KeyWord': '',
#   'LandlordNo': '',
#   'LevelGroundID': '',
#   'MRTLine': '',
#   'MRTLine2': '',
#   'MRTLine3': '',
#   'MRTLineName': '',
#   'MRTLineName2': '',
#   'MRTLineName3': '',
#   'MRTStation': '',
#   'MRTStation2': '',
# ...

# %%
from base64 import b64decode, b64encode

print(b64encode('台北市'.encode('utf8')))

print(b64decode(data.get('Method')))

for key, value in data['Data'].items():
    print(key)
    print(b64decode(value).decode('utf-8'))
# Out:
# b'5Y+w5YyX5biC'
# b'UPDATE'
# DataUnit
# 1
# DataType
#
# DataTab
#
# OrderBy
#
# OrderType
#
# CityId
# 0000
# CityId2
# 0001
# CityId3
#
# CityName
# 台北市
# CityName2
# 新北市
# CityName3
#
# AreaId
#
# AreaId2
#
# AreaId3
#
# AreaName
#
# AreaName2
#
# AreaName3
#
# PurposeID
# 2,3,4
# PriceRental
#
# PriceL
#
# PriceH
#
# MRTLine
#
# MRTLine2
#
# MRTLine3
#
# MRTLineName
#
# MRTLineName2
#
# MRTLineName3
#
# MRTStation
#
# MRTStation2
#
# MRTStation3
#
# MRTStationName
#
# MRTStationName2
#
# MRTStationName3
#
# SchoolType
#
# SchoolTypeName
#
# SchoolId
#
# SchoolName
#
# BuildingID
#
# BuildingName
#
# KeyWord
#
# KWkind
#
# KWID
#
# KWCounty
#
# KWDistrict
#
# NotRequiredOtherFeeID
#
# NotRequiredEquipmentID
#
# NotRequiredBaseMent
#
# Room
#
# LevelGroundID
#
# CaseTypeID
#
# AgentPositionID
#
# CaseFromFloor
#
# CaseToFloor
#
# BuildYear
#
# BuildYearL
#
# BuildYearH
#
# chkOTLimSex
#
# OTLimSex
#
# OTParkingSpace
#
# OTLimWithLandlord
#
# OTLimPet
#
# TGType
#
# EquipmentID
#
# ...

# %%
def encoding(string): 
    return b64encode(string.encode('utf8'))
    
def decoding(binary): 
    return b64decode(binary).decode('utf8')
    

def jsonCoding(jsonDict, code=encoding):
    
    
    return

# %%
# Out:
# b'5Y+w5YyX5biC'

# %%
import requests
import json

header = {'User-Agent':'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36'}
formData = '{"Method":"SU5RVUlSRQ==","Data":{"CityId":"MDAwMA==","CityId2":"MDAwMQ==","CityId3":"","CityName":"5Y+w5YyX5biC","CityName2":"5paw5YyX5biC","CityName3":"","AreaId":"","AreaId2":"","AreaId3":"","AreaName":"","AreaName2":"","AreaName3":"","OrderBy":"QnlVcGRhdGU=","OrderType":"RGVzYw==","MRTLine":"","MRTLine2":"","MRTLine3":"","MRTLineName":"","MRTLineName2":"","MRTLineName3":"","MRTStation":"","MRTStation2":"","MRTStation3":"","MRTStationName":"","MRTStationName2":"","MRTStationName3":"","MemberID":"","MainShopID":"","AgentName":"","CaseNo":"","DataUnit":"MQ==","KWkind":"","KWID":"","SchoolId":"","SchoolType":"","SchoolName":"","SchoolTypeName":"","KeyWord":"","BuildingID":"","BuildingName":"","PriceRental":"","PriceL":"","PriceH":"","Room":"","RoomL":"","RoomH":"","LevelGroundID":"","PinL":"","PinH":"","CaseFromFloor":"","CaseToFloor":"","BuildYear":"","BuildYearL":"","BuildYearH":"","PurposeID":"MiwzLDQ=","CaseTypeID":"","AgentPositionID":"","OTLimSex":"","OTParkingSpace":"","OTLimWithLandlord":"","OTLimPet":"","TGType":"","EquipmentID":"","DataTab":"QWxs","HavePic":"","CenterLon":"","CenterLat":"","SearchList":"5Y+w5YyX5biCIOaWsOWMl+W4giDnjajnq4vlpZfmiL8g5YiG56ef5aWX5oi/IOmbheaIvw==","Sid":"NjczNjE5NDY=","NotRequiredOtherFeeID":"","NotRequiredEquipmentID":"","NotRequiredBaseMent":"","Distance":"","OTLimToCook":"","OTPublicSquare":"","OTSideRoom":"","OTShortRent":"","BinEquipmentID":"","BinNotEquipmentID":"","OtherFeeID":"","PartitionMaterialID":"","NotPartitionMaterialID":"","LoginMemberID":"","NELat":"","NELon":"","SWLat":"","SWLon":"","BrowseMode":"U2hvd01vZGVQaWNz","chkOTLimSex":"","PMPage":"MQ=="}}'
data=json.loads(formData)

header['Cookie'] = "Cookie:ASP.NET_SessionId=ckib1lqoojsgbdkzwhcxpjca; TRID_G=edc4c176-403b-4e59-8dbb-6be535449c5c; SEID_G=a8460e25-4866-4a4d-ab54-dcb23428576c; ez2o_UNID=1502623599210210; __ltm_https_flag=true; __ltmwga=utmcsr=(direct)|utmcmd=(none); WMX_Channel=,48,; appier_tp=; appier_utmz=%7B%7D; appier_uid_2=null; appier_pv_counter7xxC2Wf0WNSEv7r=0; appier_pv_counter3I4S3xU1UAAYSdm=0; wmxuid=-1; _ga=GA1.4.1608336293.1502623600; _gid=GA1.4.1390823777.1502623600; _gat_UA-22823074-7=1; _atrk_ssid=GmO_vgQv-MkmlQhi6azLD9; _atrk_sessidx=8; _atrk_siteuid=qnmpXMW4400I9Qn4"

url = 'https://rent.housefun.com.tw/ashx/search/search.ashx?VID=120.5'


res = requests.post(url,headers=header,data=data)

# %%
for key, value in json.loads(res.text).items():
    print(key)
    print(decoding(value))
# Out:
# Method
#
# Status
# -1
# StatusMessage
# 無 Json Post Data
